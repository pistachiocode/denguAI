# %% [markdown]
# # Linear Regression
#
# ## Import libraries

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression, ElasticNetCV, ElasticNet
from sklearn.metrics import mean_absolute_error, r2_score, explained_variance_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor

# Data imputation
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV, KFold

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

sns.set_style("whitegrid")

import warnings
warnings.filterwarnings('ignore')

import dengue_utils as dutils

import xgboost as xgb
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
# Functions:

def simple_linear_regression(X, y):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=83)
    
    reg = LinearRegression(normalize=True).fit(X_train, y_train)

    y_pred = reg.predict(X_test)

    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    ex_var = explained_variance_score(y_test, y_pred)
    
    return mae, r2, ex_var

def enet(X, y):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=83)

    reg = ElasticNet(normalize=False).fit(X_train, y_train)

    y_pred = reg.predict(X_test)
    
    return y_pred, y_test

def get_metrics(y_test, y_pred):
    
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    ex_var = explained_variance_score(y_test, y_pred)
    
    return mae, r2, ex_var

def feature_engineering(df):## Add month of the year

    print("1. Including month of the year from 'week_start_date....'")
    
    if 'week_start_date' in df.columns:
        df['week_start_date'] = pd.to_datetime(df['week_start_date'])
        df['monthofyear'] = df['week_start_date'].apply(lambda x: x.month)
        
        df = df.drop(['week_start_date'], axis=1)

    # High correlation between ndvi_nw-ndvi-ne and ndvi-sw-ndvi-se
    # Add the mean of each pair that indicates the level of vegetation in the north and south of both cities.

    # Features engineering
    print("2. Including ndvi_north and  ndvi_south from ndvi_nw, ndvi_ne, ndvi_sw, ndvi_se.... ")
    
    if 'ndvi_nw' in df.columns and 'ndvi_ne' in df.columns and 'ndvi_sw' in df.columns and 'ndvi_se' in df.columns:
    
        df['ndvi_north'] = df[['ndvi_nw', 'ndvi_ne']].mean(axis=1)
        df['ndvi_south'] = df[['ndvi_sw', 'ndvi_se']].mean(axis=1)
        
        df = df.drop(['ndvi_sw', 'ndvi_nw', 'ndvi_ne', 'ndvi_se'], axis=1)

    # Conversion kelvin to celsius
    print("3. Temperature units conversion: kelvin to celsius from some features...")
    df = dutils.temperature_conversion(df)
    
    # Drop temperature features
   # df = df.drop(['reanalysis_dew_point_temp_c', 'reanalysis_max_air_temp_c', 
   #               'reanalysis_max_air_temp_c', 'reanalysis_min_air_temp_c',
   #               'reanalysis_avg_temp_c', 'reanalysis_tdtr_c', 'station_max_temp_c',
   #               'station_max_temp_c', 'station_diur_temp_rng_c', 'station_avg_temp_c',
   #              'station_min_temp_c', 'reanalysis_specific_humidity_g_per_kg'], axis=1)
   # 
    return df

# %%
# Load dataset

features_train = pd.read_csv('dengue_features_train.csv')
labels_train   = pd.read_csv('dengue_labels_train.csv')

features_test = pd.read_csv('dengue_features_test.csv')

# Join train labes and features
input_train_dataset = features_train.merge(labels_train, 
                                           left_on = ['city', 'year', 'weekofyear'], 
                                           right_on = ['city', 'year', 'weekofyear'],
                                           how = 'inner')

# %% [markdown]
# ## Preprocessing

# %%
train_dataset_city = input_train_dataset[input_train_dataset['city'].isin(["iq", "sj"])]

def preprocessing(dataset, train=True):
    # --------------------------------------
    # Feature engineering
    #---------------------------------------

    dataset = feature_engineering(dataset)
    label = 'total_cases'

    # --------------------------------------
    # Remove outiers
    #---------------------------------------

    # Remove outliers
    for feature in  dataset.columns:
        dataset[feature] = dutils.remove_outliers_iqr(dataset, feature, exclude = ['total_cases'])

    # Filling the outliers gaps
    #dataset = dataset.dropna().drop_duplicates()

    # --------------------------------------
    # Split data and label
    #---------------------------------------
    
    if train:
        # Split label and features
        dataset_label   = dataset[label]
        dataset.drop([label], axis=1)

    # Drop city column because is not numeric and label column (total_cases)
    features_lreg = dataset.columns.drop(['city'])

    dataset = dataset[features_lreg]


    # --------------------------------------
    # Scaling and data imputation
    #---------------------------------------

    # Data imputation
    imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
    dataset_train_imp = pd.DataFrame(imp.fit_transform(dataset))

    # Set columns name
    dataset_train_imp.columns = dataset.columns
    dataset_train_imp.index   = dataset.index


    # Scale data (features)
    scaler = StandardScaler().fit(dataset_train_imp)
    dataset = pd.DataFrame(scaler.transform(dataset_train_imp), 
                           columns = dataset_train_imp.columns)

    
    if train:
        dataset[label] = dataset_label
    
    return dataset

# %%
dataset_train = preprocessing(train_dataset_city)
dataset_train.describe().T
# Out:
# 1. Including month of the year from 'week_start_date....'
# 2. Including ndvi_north and  ndvi_south from ndvi_nw, ndvi_ne, ndvi_sw, ndvi_se....
# 3. Temperature units conversion: kelvin to celsius from some features...
# 20190414 - 11:M:30: Temperature conversion: kelvin to celsius reanalysis_air_temp_k to reanalysis_air_temp_c
# 20190414 - 11:M:30: Temperature conversion: kelvin to celsius reanalysis_dew_point_temp_k to reanalysis_dew_point_temp_c
# 20190414 - 11:M:30: Temperature conversion: kelvin to celsius reanalysis_max_air_temp_k to reanalysis_max_air_temp_c
# 20190414 - 11:M:30: Temperature conversion: kelvin to celsius reanalysis_min_air_temp_k to reanalysis_min_air_temp_c
# 20190414 - 11:M:30: Temperature conversion: kelvin to celsius reanalysis_avg_temp_k to reanalysis_avg_temp_c
# 20190414 - 11:M:30: Temperature conversion: kelvin to celsius reanalysis_tdtr_k to reanalysis_tdtr_c
#                                         count          mean        std  \
# year                                   1456.0 -4.980753e-16   1.000344
# weekofyear                             1456.0 -1.544095e-18   1.000344
# precipitation_amt_mm                   1456.0  1.519008e-15   1.000344
# reanalysis_precip_amt_kg_per_m2        1456.0  7.861538e-17   1.000344
# reanalysis_relative_humidity_percent   1456.0 -9.253129e-16   1.000344
# reanalysis_sat_precip_amt_mm           1456.0  1.519008e-15   1.000344
# reanalysis_specific_humidity_g_per_kg  1456.0 -2.026195e-15   1.000344
# station_avg_temp_c                     1456.0  2.317019e-15   1.000344
# station_diur_temp_rng_c                1456.0 -2.192233e-16   1.000344
# station_max_temp_c                     1456.0 -5.084455e-16   1.000344
# station_min_temp_c                     1456.0  1.979007e-15   1.000344
# station_precip_mm                      1456.0  4.272757e-16   1.000344
# total_cases                            1456.0  2.467514e+01  43.596000
# monthofyear                            1456.0 -6.820704e-17   1.000344
# ndvi_north                             1456.0 -6.557636e-16   1.000344
# ndvi_south                             1456.0 -8.775032e-16   1.000344
# reanalysis_air_temp_c                  1456.0  4.405816e-16   1.000344
# reanalysis_dew_point_temp_c            1456.0 -3.969657e-16   1.000344
# reanalysis_max_air_temp_c              1456.0 -1.536164e-15   1.000344
# reanalysis_min_air_temp_c              1456.0 -1.107325e-15   1.000344
# reanalysis_avg_temp_c                  1456.0  2.562816e-16   1.000344
# reanalysis_tdtr_c                      1456.0 -5.529765e-16   1.000344
#
#                                             min       25%        50%  \
# year                                  -2.040448 -0.745700   0.179120
# weekofyear                            -1.698612 -0.849420  -0.000229
# precipitation_amt_mm                  -1.167562 -0.896450  -0.113873
# reanalysis_precip_amt_kg_per_m2       -1.327552 -0.779328  -0.190817
# reanalysis_relative_humidity_percent  -2.478251 -0.699407  -0.256337
# reanalysis_sat_precip_amt_mm          -1.167562 -0.896450  -0.113873
# reanalysis_specific_humidity_g_per_kg -3.125843 -0.774184   0.205810
# station_avg_temp_c                    -2.888981 -0.649795   0.146424
# station_diur_temp_rng_c               -1.697095 -0.731697  -0.317956
# station_max_temp_c                    -2.748821 -0.706595   0.183606
# station_min_temp_c                    -2.828422 -0.720917   0.026907
# station_precip_mm                     -1.116980 -0.795859  -0.229814
# total_cases                            0.000000  5.000000  12.000000
# monthofyear                           -1.570230 -0.773272   0.023686
# ndvi_north                            -2.915650 -0.711659  -0.054082
# ndvi_south                            -2.617865 -0.686819  -0.086700
# reanalysis_air_temp_c                 -2.995836 -0.763929  -0.029257
# reanalysis_dew_point_temp_c           -3.132234 -0.750919   0.239607
# reanalysis_max_air_temp_c             -1.779380 -0.755563  -0.275650
# reanalysis_min_air_temp_c             -3.063764 -0.712111   0.178514
# reanalysis_avg_temp_c                 -3.054209 -0.765215   0.029277
# reanalysis_tdtr_c                     -1.005097 -0.729199  -0.577049
#
#                                              75%         max
# year                                    0.734012    1.658833
# weekofyear                              0.848963    1.764758
# precipitation_amt_mm                    0.665915    3.129401
# reanalysis_precip_amt_kg_per_m2         0.474944    3.245140
# reanalysis_relative_humidity_percent    0.543795    2.320114
# reanalysis_sat_precip_amt_mm            0.665915    3.129401
# reanalysis_specific_humidity_g_per_kg   0.799965    2.424268
# station_avg_temp_c                      0.744307    2.894386
# station_diur_temp_rng_c                 0.702607    2.939111
# station_max_temp_c                      0.759618    2.749479
# station_min_temp_c                      0.774732    2.338365
# station_precip_mm                       0.461413    3.280751
# total_cases                            28.000000  461.000000
# monthofyear                             0.748193    1.617602
# ndvi_north                              0.734493    2.863420
# ndvi_south                              0.583494    2.705942
# reanalysis_air_temp_c                   0.829351    2.577354
# reanalysis_dew_point_temp_c             0.800215    2.146395
# reanalysis_max_air_temp_c               0.628188    2.827793
# reanalysis_min_air_temp_c               0.858992    1.659555
# reanalysis_avg_temp_c                   0.782254    2.963885
# reanalysis_tdtr_c                       0.748683    2.999487

# %%
dataset_test= preprocessing(features_test, train=False)
dataset_test.describe().T
# Out:
# 1. Including month of the year from 'week_start_date....'
# 2. Including ndvi_north and  ndvi_south from ndvi_nw, ndvi_ne, ndvi_sw, ndvi_se....
# 3. Temperature units conversion: kelvin to celsius from some features...
# 20190414 - 11:M:35: Temperature conversion: kelvin to celsius reanalysis_air_temp_k to reanalysis_air_temp_c
# 20190414 - 11:M:35: Temperature conversion: kelvin to celsius reanalysis_dew_point_temp_k to reanalysis_dew_point_temp_c
# 20190414 - 11:M:36: Temperature conversion: kelvin to celsius reanalysis_max_air_temp_k to reanalysis_max_air_temp_c
# 20190414 - 11:M:36: Temperature conversion: kelvin to celsius reanalysis_min_air_temp_k to reanalysis_min_air_temp_c
# 20190414 - 11:M:36: Temperature conversion: kelvin to celsius reanalysis_avg_temp_k to reanalysis_avg_temp_c
# 20190414 - 11:M:36: Temperature conversion: kelvin to celsius reanalysis_tdtr_k to reanalysis_tdtr_c
#                                        count          mean       std  \
# year                                   416.0  1.417136e-14  1.001204
# weekofyear                             416.0 -9.246577e-17  1.001204
# precipitation_amt_mm                   416.0 -1.414467e-17  1.001204
# reanalysis_precip_amt_kg_per_m2        416.0  3.509479e-17  1.001204
# reanalysis_relative_humidity_percent   416.0  2.295173e-16  1.001204
# reanalysis_sat_precip_amt_mm           416.0 -1.414467e-17  1.001204
# reanalysis_specific_humidity_g_per_kg  416.0  1.110223e-15  1.001204
# station_avg_temp_c                     416.0 -2.551128e-16  1.001204
# station_diur_temp_rng_c                416.0  5.876709e-16  1.001204
# station_max_temp_c                     416.0  3.793707e-16  1.001204
# station_min_temp_c                     416.0  9.133986e-16  1.001204
# station_precip_mm                      416.0 -1.574595e-17  1.001204
# monthofyear                            416.0 -4.570329e-17  1.001204
# ndvi_north                             416.0 -2.407262e-16  1.001204
# ndvi_south                             416.0  9.500947e-17  1.001204
# reanalysis_air_temp_c                  416.0 -1.869765e-15  1.001204
# reanalysis_dew_point_temp_c            416.0 -1.765415e-15  1.001204
# reanalysis_max_air_temp_c              416.0  1.435284e-15  1.001204
# reanalysis_min_air_temp_c              416.0  2.423275e-16  1.001204
# reanalysis_avg_temp_c                  416.0  9.871911e-16  1.001204
# reanalysis_tdtr_c                      416.0  4.782499e-16  1.001204
#
#                                             min       25%       50%       75%  \
# year                                  -1.930646 -0.535079  0.162704  0.860488
# weekofyear                            -1.700501 -0.848242 -0.029405  0.839565
# precipitation_amt_mm                  -1.149141 -0.888086 -0.149514  0.606912
# reanalysis_precip_amt_kg_per_m2       -1.123860 -0.798693 -0.236416  0.443729
# reanalysis_relative_humidity_percent  -2.391294 -0.693702 -0.292039  0.745200
# reanalysis_sat_precip_amt_mm          -1.149141 -0.888086 -0.149514  0.606912
# reanalysis_specific_humidity_g_per_kg -2.828134 -0.728865  0.254046  0.802332
# station_avg_temp_c                    -2.647920 -0.693223  0.052544  0.749248
# station_diur_temp_rng_c               -1.562803 -0.774793 -0.448925  0.804189
# station_max_temp_c                    -2.815973 -0.751782  0.147993  0.730200
# station_min_temp_c                    -2.724227 -0.796594 -0.154050  0.552749
# station_precip_mm                     -1.190124 -0.824563 -0.235880  0.486278
# monthofyear                           -1.570512 -0.773057  0.024398  0.749356
# ndvi_north                            -2.587704 -0.802759 -0.228770  0.824791
# ndvi_south                            -2.635870 -0.751216 -0.064652  0.625419
# reanalysis_air_temp_c                 -2.912191 -0.728638 -0.173481  0.969762
# reanalysis_dew_point_temp_c           -3.034036 -0.700124  0.258239  0.807507
# reanalysis_max_air_temp_c             -1.771295 -0.696652 -0.261873  0.722533
# reanalysis_min_air_temp_c             -2.754227 -0.836084  0.178319  0.906844
# reanalysis_avg_temp_c                 -3.163512 -0.788532 -0.018824  0.897691
# reanalysis_tdtr_c                     -1.030816 -0.756641 -0.626130  0.863115
#
#                                             max
# year                                   1.558271
# weekofyear                             1.775379
# precipitation_amt_mm                   3.042025
# reanalysis_precip_amt_kg_per_m2        3.220847
# reanalysis_relative_humidity_percent   2.106081
# reanalysis_sat_precip_amt_mm           3.042025
# reanalysis_specific_humidity_g_per_kg  1.721050
# station_avg_temp_c                     2.391900
# station_diur_temp_rng_c                2.867530
# station_max_temp_c                     2.582678
# station_min_temp_c                     2.351872
# station_precip_mm                      2.997396
# monthofyear                            1.619307
# ndvi_north                             2.647232
# ndvi_south                             2.766886
# reanalysis_air_temp_c                  2.129104
# reanalysis_dew_point_temp_c            1.575244
# reanalysis_max_air_temp_c              2.691345
# reanalysis_min_air_temp_c              1.450933
# reanalysis_avg_temp_c                  3.054519
# reanalysis_tdtr_c                      2.651828

# %% [markdown]
# ## Training models

# %%
# --------------------------------------
# Split dataset in test and training
#---------------------------------------
X_train, X_test, y_train, y_test = train_test_split(dataset_train, 
                                                    dataset_train['total_cases'], 
                                                    test_size = 0.2, 
                                                    random_state=83)

# --------------------------------------
# Training models
#---------------------------------------

# Elastic Net
enet   = ElasticNet(normalize = False).fit(X_train, y_train)
y_pred_enet = enet.predict(X_test)

metrics_enet = get_metrics(y_test, y_pred_enet)
print(metrics_enet)

# Decision Tree
tree_reg   = DecisionTreeRegressor(max_depth=5).fit(X_train, y_train)
y_pred_tree = tree_reg.predict(X_test)

metrics_tree = get_metrics(y_test, y_pred_tree)
print(metrics_tree)

#Ensemble
ensemble_reg = GradientBoostingRegressor(max_depth=5, n_estimators=5, learning_rate=1.0, random_state = 83)
ensemble_reg = ensemble_reg.fit(X_train, y_train)
y_pred_ensemble = ensemble_reg.predict(X_test)

metrics_ensemble = get_metrics(y_test, y_pred_ensemble)
print(metrics_ensemble)

#XGBoost

xgb_model = xgb.XGBRegressor(objective="reg:linear", random_state=83)
xgb_model = xgb_model.fit(X_train, y_train)

y_pred_xgb = xgb_model.predict(X_test)

metrics_xgb = get_metrics(y_test, y_pred_xgb)
print(metrics_xgb)

df_test = pd.DataFrame(list(y_test), columns=['y_test'])
y_pred_xgb = pd.DataFrame(list(y_pred_tree), columns=['y_pred_xgb'])

df = pd.concat([df_test, y_pred_xgb], axis=1)


ax = sns.scatterplot(x="y_test", y="y_pred_xgb", data=df)
# Out:
# (0.011546579892945196, 0.9999997369238753, 0.9999997378800136)
# (2.1327083546673715, 0.9439199652883463, 0.9441583970802925)
# (1.6237379686585576, 0.9545549499832712, 0.9547759101734541)
# (0.43983047312661394, 0.9959338651104217, 0.9959404000597915)

# %%
## Prepare submision

# %%
# Save predictions

# %%
kf = KFold(n_splits=2, shuffle=True, random_state=83)
for train_index, test_index in kf.split(X_train):
    
    xgb_model = xgb.XGBRegressor().fit(X_train.iloc[train_index], y_train[train_index])
    y_pred = xgb_model.predict(X_train.iloc[test_index])
    actuals = y_test[test_index]
    print(mean_absolute_error(actuals, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-8bde8e016b21> in <module>
#       5     y_pred = xgb_model.predict(X_train.iloc[test_index])
#       6     actuals = y_test[test_index]
# ----> 7     print(mean_absolute_error(actuals, y_pred))
#
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     168     """
#     169     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 170         y_true, y_pred, multioutput)
#     171     output_errors = np.average(np.abs(y_pred - y_true),
#     172                                weights=sample_weight, axis=0)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      74     """
#      75     check_consistent_length(y_true, y_pred)
# ---> 76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#      78
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
## Tune GradientBoostingRegressor

#Enselmble
ensemble_reg = GradientBoostingRegressor(max_depth=5, n_estimators=3, 
                                         learning_rate=1.0, random_state = 83).fit(X_train, y_train)
y_pred_ensemble = ensemble_reg.predict(X_test)

metrics_ensemble = get_metrics(y_test, y_pred_ensemble)
print(metrics_ensemble)
# Out:
# (11.502098851389183, 0.4315822478757181, 0.43224569791384826)

# %% [markdown]
# ## PCA
#
# https://georgemdallas.wordpress.com/2013/10/30/principal-component-analysis-4-dummies-eigenvectors-eigenvalues-and-dimension-reduction/

# %%
from sklearn.decomposition import PCA

pca = PCA()

principalComponents = pca.fit_transform(train_dataset_scaled)
principalDf = pd.DataFrame(data = principalComponents)

#Plotting the Cumulative Summation of the Explained Variance
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Dataset Explained Variance')
plt.show()

# %%
pca = PCA(n_components=12)
dataset_train = pca.fit_transform(train_dataset_scaled)
#dataset = pd.DataFrame(dataset, columns = ['pca_comp1', 'pca_comp2', 'pca_comp3', 'pca_comp4', 'pca_comp5'])
dataset_train.shape
# Out:
# (1154, 12)

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset_train, 
                                                    train_label, 
                                                    test_size = 0.2, 
                                                    random_state=83)

xgb_model = xgb.XGBRegressor(objective="reg:linear", random_state=83)
xgb_model = xgb_model.fit(X_train, y_train)

y_pred_xgb = xgb_model.predict(X_test)

metrics_xgb = get_metrics(y_test, y_pred_xgb)
print(metrics_xgb)
# Out:
# (16.407204931819592, 0.29656546571277864, 0.29754824508676314)
