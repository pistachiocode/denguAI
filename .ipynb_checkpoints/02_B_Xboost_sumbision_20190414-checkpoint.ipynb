# %% [markdown]
# # Linear Regression
#
# ## Import libraries

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression, ElasticNetCV, ElasticNet
from sklearn.metrics import mean_absolute_error, r2_score, explained_variance_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor

# Data imputation
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV, KFold

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

sns.set_style("whitegrid")

import warnings
warnings.filterwarnings('ignore')

import dengue_utils as dutils

import xgboost as xgb
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
# Functions:

def simple_linear_regression(X, y):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=83)
    
    reg = LinearRegression(normalize=True).fit(X_train, y_train)

    y_pred = reg.predict(X_test)

    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    ex_var = explained_variance_score(y_test, y_pred)
    
    return mae, r2, ex_var

def enet(X, y):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=83)

    reg = ElasticNet(normalize=False).fit(X_train, y_train)

    y_pred = reg.predict(X_test)
    
    return y_pred, y_test

def get_metrics(y_test, y_pred):
    
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    ex_var = explained_variance_score(y_test, y_pred)
    
    return mae, r2, ex_var

def feature_engineering(df):## Add month of the year

    print("1. Including month of the year from 'week_start_date....'")
    if 'week_start_date' in df.columns:
        df['week_start_date'] = pd.to_datetime(df['week_start_date'])
        df['monthofyear'] = df['week_start_date'].apply(lambda x: x.month)

    # High correlation between ndvi_nw-ndvi-ne and ndvi-sw-ndvi-se
    # Add the mean of each pair that indicates the level of vegetation in the north and south of both cities.

    # Features engineering
    print("2. Including ndvi_north and  ndvi_south from ndvi_nw, ndvi_ne, ndvi_sw, ndvi_se.... ")
    if 'ndvi_nw' in df.columns and 'ndvi_ne' in df.columns:
        df['ndvi_north'] = df[['ndvi_nw', 'ndvi_ne']].mean(axis=1)
        
    if 'ndvi_sw' in df.columns and 'ndvi_se' in df.columns:    
        df['ndvi_south'] = df[['ndvi_sw', 'ndvi_se']].mean(axis=1)

    #Remove feature

    df = df.drop(['ndvi_sw', 'ndvi_nw', 'ndvi_ne', 'ndvi_se', 'week_start_date'], axis=1)

    # Conversion kelvin to celsius
    print("3. Temperature units conversion: kelvin to celsius from some features...")
    df = dutils.temperature_conversion(df)
    
    # Drop temperature features
   # df = df.drop(['reanalysis_dew_point_temp_c', 'reanalysis_max_air_temp_c', 
   #               'reanalysis_max_air_temp_c', 'reanalysis_min_air_temp_c',
   #               'reanalysis_avg_temp_c', 'reanalysis_tdtr_c', 'station_max_temp_c',
   #               'station_max_temp_c', 'station_diur_temp_rng_c', 'station_avg_temp_c',
   #              'station_min_temp_c', 'reanalysis_specific_humidity_g_per_kg'], axis=1)
   # 
    return df

# %%
# Load dataset

features_train = pd.read_csv('dengue_features_train.csv')
labels_train   = pd.read_csv('dengue_labels_train.csv')

features_test = pd.read_csv('dengue_features_test.csv')

# Join train labes and features
input_train_dataset = features_train.merge(labels_train, 
                                           left_on = ['city', 'year', 'weekofyear'], 
                                           right_on = ['city', 'year', 'weekofyear'],
                                           how = 'inner')

# %%
# Feature engineering
input_train_dataset = feature_engineering(input_train_dataset)
input_train_dataset = input_train_dataset

label = 'total_cases'
# Out:
# 1. Including month of the year from 'week_start_date....'
# 2. Including ndvi_north and  ndvi_south from ndvi_nw, ndvi_ne, ndvi_sw, ndvi_se....
# 3. Temperature units conversion: kelvin to celsius from some features...
# 20190414 - 01:M:49: Temperature conversion: kelvin to celsius reanalysis_air_temp_k to reanalysis_air_temp_c
# 20190414 - 01:M:49: Temperature conversion: kelvin to celsius reanalysis_dew_point_temp_k to reanalysis_dew_point_temp_c
# 20190414 - 01:M:49: Temperature conversion: kelvin to celsius reanalysis_max_air_temp_k to reanalysis_max_air_temp_c
# 20190414 - 01:M:49: Temperature conversion: kelvin to celsius reanalysis_min_air_temp_k to reanalysis_min_air_temp_c
# 20190414 - 01:M:49: Temperature conversion: kelvin to celsius reanalysis_avg_temp_k to reanalysis_avg_temp_c
# 20190414 - 01:M:49: Temperature conversion: kelvin to celsius reanalysis_tdtr_k to reanalysis_tdtr_c

# %%
input_train_dataset.columns
# Out:
# Index(['city', 'year', 'weekofyear', 'precipitation_amt_mm',
#        'reanalysis_precip_amt_kg_per_m2',
#        'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
#        'reanalysis_specific_humidity_g_per_kg', 'station_avg_temp_c',
#        'station_diur_temp_rng_c', 'station_max_temp_c', 'station_min_temp_c',
#        'station_precip_mm', 'total_cases', 'monthofyear', 'ndvi_north',
#        'ndvi_south', 'reanalysis_air_temp_c', 'reanalysis_dew_point_temp_c',
#        'reanalysis_max_air_temp_c', 'reanalysis_min_air_temp_c',
#        'reanalysis_avg_temp_c', 'reanalysis_tdtr_c'],
#       dtype='object')

# %%
input_train_dataset['city'].unique()
# Out:
# array(['sj', 'iq'], dtype=object)

# %% [markdown]
# ## Data imputation + Simple linear regression

# %%
train_dataset_city = input_train_dataset[input_train_dataset['city'].isin(["iq", "sj"])]


# --------------------------------------
# Scaling and data imputation
#---------------------------------------

# Remove outliers
for feature in  train_dataset_city.columns:
    train_dataset_city[feature] = dutils.remove_outliers_iqr(train_dataset_city, 
                                                               feature, 
                                                               exclude = ['total_cases'])
    
train_dataset_city.describe().T
# Out:
#                                         count         mean        std  \
# year                                   1456.0  2001.031593   5.408314
# weekofyear                             1456.0    26.503434  15.019437
# precipitation_amt_mm                   1419.0    42.893404  37.226576
# reanalysis_precip_amt_kg_per_m2        1359.0    31.964430  24.931370
# reanalysis_relative_humidity_percent   1444.0    82.193743   7.107425
# reanalysis_sat_precip_amt_mm           1419.0    42.893404  37.226576
# reanalysis_specific_humidity_g_per_kg  1445.0    16.749908   1.537335
# station_avg_temp_c                     1407.0    27.203785   1.264379
# station_diur_temp_rng_c                1410.0     8.044419   2.105955
# station_max_temp_c                     1432.0    32.449372   1.926290
# station_min_temp_c                     1425.0    22.160421   1.487369
# station_precip_mm                      1354.0    30.783604  28.589443
# total_cases                            1456.0    24.675137  43.596000
# monthofyear                            1456.0     6.418269   3.451806
# ndvi_north                             1416.0     0.132553   0.123579
# ndvi_south                             1410.0     0.199828   0.069840
# reanalysis_air_temp_c                  1446.0    25.551852   1.362420
# reanalysis_dew_point_temp_c            1439.0    22.120814   1.490416
# reanalysis_max_air_temp_c              1436.0    30.211560   3.148348
# reanalysis_min_air_temp_c              1440.0    22.604028   2.512957
# reanalysis_avg_temp_c                  1444.0    26.081337   1.253035
# reanalysis_tdtr_c                      1445.0  -268.253945   3.535564
#
#                                                min          25%          50%  \
# year                                   1990.000000  1997.000000  2002.000000
# weekofyear                                1.000000    13.750000    26.500000
# precipitation_amt_mm                      0.000000     9.550000    37.300000
# reanalysis_precip_amt_kg_per_m2           0.000000    12.425000    25.300000
# reanalysis_relative_humidity_percent     64.658571    77.196429    80.305714
# reanalysis_sat_precip_amt_mm              0.000000     9.550000    37.300000
# reanalysis_specific_humidity_g_per_kg    11.964286    15.561429    17.088571
# station_avg_temp_c                       23.614286    26.314286    27.428571
# station_diur_temp_rng_c                   4.528571     6.514286     7.300000
# station_max_temp_c                       27.200000    31.100000    32.800000
# station_min_temp_c                       18.000000    21.100000    22.200000
# station_precip_mm                         0.000000     8.100000    21.200000
# total_cases                               0.000000     5.000000    12.000000
# monthofyear                               1.000000     3.750000     6.500000
# ndvi_north                               -0.222650     0.044225     0.121050
# ndvi_south                                0.019971     0.151371     0.191518
# reanalysis_air_temp_c                    21.485714    24.508929    25.496429
# reanalysis_dew_point_temp_c              17.481429    20.992143    22.495714
# reanalysis_max_air_temp_c                24.650000    27.850000    29.250000
# reanalysis_min_air_temp_c                14.950000    20.750000    23.050000
# reanalysis_avg_temp_c                    22.271429    25.112500    26.142857
# reanalysis_tdtr_c                      -271.792857  -270.821429  -270.292857
#
#                                                75%          max
# year                                   2005.000000  2010.000000
# weekofyear                               39.250000    53.000000
# precipitation_amt_mm                     68.175000   157.860000
# reanalysis_precip_amt_kg_per_m2          45.325000   110.100000
# reanalysis_relative_humidity_percent     86.406429    98.610000
# reanalysis_sat_precip_amt_mm             68.175000   157.860000
# reanalysis_specific_humidity_g_per_kg    17.978571    20.461429
# station_avg_temp_c                       28.164286    30.800000
# station_diur_temp_rng_c                   9.550000    14.133333
# station_max_temp_c                       33.900000    37.700000
# station_min_temp_c                       23.300000    25.600000
# station_precip_mm                        46.275000   121.200000
# total_cases                              28.000000   461.000000
# monthofyear                               9.000000    12.000000
# ndvi_north                                0.225388     0.481393
# ndvi_south                                0.242090     0.385736
# reanalysis_air_temp_c                    26.683571    29.050000
# reanalysis_dew_point_temp_c              23.315000    25.300000
# reanalysis_max_air_temp_c                32.350000    39.050000
# reanalysis_min_air_temp_c                24.775000    26.750000
# reanalysis_avg_temp_c                    27.057143    29.778571
# reanalysis_tdtr_c                      -265.535714  -257.692857

# %%
# Filling the outliers gaps
train_dataset_city = train_dataset_city.dropna().drop_duplicates()
train_dataset_city.describe().T
# Out:
#                                         count         mean        std  \
# year                                   1154.0  2000.545061   5.421693
# weekofyear                             1154.0    26.098787  14.606511
# precipitation_amt_mm                   1154.0    38.582357  34.899085
# reanalysis_precip_amt_kg_per_m2        1154.0    30.513778  24.045652
# reanalysis_relative_humidity_percent   1154.0    81.130536   6.367348
# reanalysis_sat_precip_amt_mm           1154.0    38.582357  34.899085
# reanalysis_specific_humidity_g_per_kg  1154.0    16.694832   1.506950
# station_avg_temp_c                     1154.0    27.195603   1.293946
# station_diur_temp_rng_c                1154.0     7.853333   2.008874
# station_max_temp_c                     1154.0    32.300953   1.902769
# station_min_temp_c                     1154.0    22.252426   1.515705
# station_precip_mm                      1154.0    28.774437  27.314669
# total_cases                            1154.0    23.029463  31.300311
# monthofyear                            1154.0     6.378683   3.360853
# ndvi_north                             1154.0     0.115648   0.117711
# ndvi_south                             1154.0     0.195550   0.066962
# reanalysis_air_temp_c                  1154.0    25.697404   1.342616
# reanalysis_dew_point_temp_c            1154.0    22.064288   1.488377
# reanalysis_max_air_temp_c              1154.0    29.868804   3.033419
# reanalysis_min_air_temp_c              1154.0    22.961092   2.407065
# reanalysis_avg_temp_c                  1154.0    26.137763   1.235628
# reanalysis_tdtr_c                      1154.0  -268.722184   3.331988
#
#                                                min          25%          50%  \
# year                                   1990.000000  1996.000000  2001.000000
# weekofyear                                1.000000    14.000000    26.000000
# precipitation_amt_mm                      0.000000     6.650000    32.055000
# reanalysis_precip_amt_kg_per_m2           0.000000    11.907500    23.905000
# reanalysis_relative_humidity_percent     65.284286    76.873214    79.628571
# reanalysis_sat_precip_amt_mm              0.000000     6.650000    32.055000
# reanalysis_specific_humidity_g_per_kg    12.481429    15.477857    16.991429
# station_avg_temp_c                       23.614286    26.251786    27.430952
# station_diur_temp_rng_c                   4.528571     6.485714     7.142857
# station_max_temp_c                       27.200000    31.100000    32.800000
# station_min_temp_c                       18.000000    21.100000    22.200000
# station_precip_mm                         0.000000     7.900000    20.050000
# total_cases                               0.000000     5.000000    13.000000
# monthofyear                               1.000000     4.000000     6.000000
# ndvi_north                               -0.222650     0.034534     0.098800
# ndvi_south                                0.030283     0.149761     0.187542
# reanalysis_air_temp_c                    21.700000    24.654286    25.647143
# reanalysis_dew_point_temp_c              17.481429    20.885000    22.405000
# reanalysis_max_air_temp_c                24.650000    27.650000    29.050000
# reanalysis_min_air_temp_c                15.150000    21.350000    23.450000
# reanalysis_avg_temp_c                    22.271429    25.171429    26.221429
# reanalysis_tdtr_c                      -271.578571  -270.864286  -270.435714
#
#                                                75%          max
# year                                   2005.000000  2010.000000
# weekofyear                               38.000000    52.000000
# precipitation_amt_mm                     62.357500   151.120000
# reanalysis_precip_amt_kg_per_m2          42.647500   110.100000
# reanalysis_relative_humidity_percent     83.320714    98.134286
# reanalysis_sat_precip_amt_mm             62.357500   151.120000
# reanalysis_specific_humidity_g_per_kg    17.948214    20.091429
# station_avg_temp_c                       28.214286    30.071429
# station_diur_temp_rng_c                   8.800000    14.133333
# station_max_temp_c                       33.600000    37.400000
# station_min_temp_c                       23.300000    25.600000
# station_precip_mm                        41.000000   121.200000
# total_cases                              29.000000   329.000000
# monthofyear                               9.000000    12.000000
# ndvi_north                                0.198637     0.422900
# ndvi_south                                0.236779     0.385736
# reanalysis_air_temp_c                    26.800714    29.050000
# reanalysis_dew_point_temp_c              23.295714    24.991429
# reanalysis_max_air_temp_c                31.250000    39.050000
# reanalysis_min_air_temp_c                24.950000    26.750000
# reanalysis_avg_temp_c                    27.107143    29.464286
# reanalysis_tdtr_c                      -266.682143  -257.692857

# %%
# Split label and features
train_label   = train_dataset_city[label]

# %%
train_dataset_city = input_train_dataset[input_train_dataset['city'].isin(["iq", "sj"])]


# --------------------------------------
# Scaling and data imputation
#---------------------------------------

# Remove outliers
#for feature in  train_dataset_city.columns:
#    train_dataset_city[feature] = dutils.remove_outliers_iqr(train_dataset_city, 
#                                                               feature, 
#                                                               exclude = ['total_cases'])

# Filling the outliers gaps
#train_dataset_city = train_dataset_city.dropna().drop_duplicates()
#features_test = features_test.dropna().drop_duplicates()

# Split label and features
train_label   = train_dataset_city[label]

# Drop city  column because is not numeric and label column (total_cases)
features_lreg = train_dataset_city.columns.drop(['city', 'total_cases'])

train_dataset_city = train_dataset_city[features_lreg]

# --------------------------------------
# Scaling and data imputation
#---------------------------------------

# Data imputation
imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
train_dataset_imputed = pd.DataFrame(imp.fit_transform(train_dataset_city))

# Set columns name
train_dataset_imputed.columns = train_dataset_city.columns
train_dataset_imputed.index   = train_dataset_city.index


# Scale data (features)
scaler = StandardScaler().fit(train_dataset_imputed)
train_dataset_scaled = pd.DataFrame(scaler.transform(train_dataset_imputed), 
                                    columns = train_dataset_imputed.columns)

# %%
# --------------------------------------
# Split dataset in test and training
#---------------------------------------
X_train, X_test, y_train, y_test = train_test_split(train_dataset_scaled, 
                                                    train_label, 
                                                    test_size = 0.2, 
                                                    random_state=83)

# --------------------------------------
# Training models
#---------------------------------------

# Elastic Net
enet   = ElasticNet(normalize = False).fit(X_train, y_train)
y_pred_enet = enet.predict(X_test)

metrics_enet = get_metrics(y_test, y_pred_enet)
print(metrics_enet)

# Decision Tree
tree_reg   = DecisionTreeRegressor(max_depth=5).fit(X_train, y_train)
y_pred_tree = tree_reg.predict(X_test)

metrics_tree = get_metrics(y_test, y_pred_tree)
print(metrics_tree)

#Ensemble
ensemble_reg = GradientBoostingRegressor(max_depth=5, n_estimators=5, learning_rate=1.0, random_state = 83)
ensemble_reg = ensemble_reg.fit(X_train, y_train)
y_pred_ensemble = ensemble_reg.predict(X_test)

metrics_ensemble = get_metrics(y_test, y_pred_ensemble)
print(metrics_ensemble)

#XGBoost

xgb_model = xgb.XGBRegressor(objective="reg:linear", random_state=83)
xgb_model = xgb_model.fit(X_train, y_train)

y_pred_xgb = xgb_model.predict(X_test)

metrics_xgb = get_metrics(y_test, y_pred_xgb)
print(metrics_xgb)

df_test = pd.DataFrame(list(y_test), columns=['y_test'])
y_pred_xgb = pd.DataFrame(list(y_pred_tree), columns=['y_pred_xgb'])

df = pd.concat([df_test, y_pred_xgb], axis=1)


ax = sns.scatterplot(x="y_pred_xgb", y="y_test", data=df)
# Out:
# (18.854422518594912, 0.188925700097328, 0.18915544110585947)
# (15.912599674714135, 0.2044630035517202, 0.21412175552694512)
# (14.105338414575664, 0.33700184150279355, 0.34688778334543646)
# (11.477612694648847, 0.7398642179159765, 0.740852114749486)

# %%
# Save predictions

# %%
kf = KFold(n_splits=2, shuffle=True, random_state=83)
for train_index, test_index in kf.split(X_train):
    
    xgb_model = xgb.XGBRegressor().fit(X_train.iloc[train_index], y_train[train_index])
    y_pred = xgb_model.predict(X_train.iloc[test_index])
    actuals = y_test[test_index]
    print(mean_absolute_error(actuals, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-8bde8e016b21> in <module>
#       5     y_pred = xgb_model.predict(X_train.iloc[test_index])
#       6     actuals = y_test[test_index]
# ----> 7     print(mean_absolute_error(actuals, y_pred))
#
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     168     """
#     169     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 170         y_true, y_pred, multioutput)
#     171     output_errors = np.average(np.abs(y_pred - y_true),
#     172                                weights=sample_weight, axis=0)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      74     """
#      75     check_consistent_length(y_true, y_pred)
# ---> 76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#      78
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
## Tune GradientBoostingRegressor

#Enselmble
ensemble_reg = GradientBoostingRegressor(max_depth=5, n_estimators=3, 
                                         learning_rate=1.0, random_state = 83).fit(X_train, y_train)
y_pred_ensemble = ensemble_reg.predict(X_test)

metrics_ensemble = get_metrics(y_test, y_pred_ensemble)
print(metrics_ensemble)
# Out:
# (11.502098851389183, 0.4315822478757181, 0.43224569791384826)

# %% [markdown]
# ## PCA
#
# https://georgemdallas.wordpress.com/2013/10/30/principal-component-analysis-4-dummies-eigenvectors-eigenvalues-and-dimension-reduction/

# %%
from sklearn.decomposition import PCA

pca = PCA()

principalComponents = pca.fit_transform(train_dataset_scaled)
principalDf = pd.DataFrame(data = principalComponents)

#Plotting the Cumulative Summation of the Explained Variance
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Dataset Explained Variance')
plt.show()

# %%
pca = PCA(n_components=12)
dataset_train = pca.fit_transform(train_dataset_scaled)
#dataset = pd.DataFrame(dataset, columns = ['pca_comp1', 'pca_comp2', 'pca_comp3', 'pca_comp4', 'pca_comp5'])
dataset_train.shape
# Out:
# (1154, 12)

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset_train, 
                                                    train_label, 
                                                    test_size = 0.2, 
                                                    random_state=83)

xgb_model = xgb.XGBRegressor(objective="reg:linear", random_state=83)
xgb_model = xgb_model.fit(X_train, y_train)

y_pred_xgb = xgb_model.predict(X_test)

metrics_xgb = get_metrics(y_test, y_pred_xgb)
print(metrics_xgb)
# Out:
# (16.407204931819592, 0.29656546571277864, 0.29754824508676314)
