# %% [markdown]
# # DengAI Competition
#
# ## Import libraries

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

import dengue_utils as dutils
import dsutils as du

# %% [markdown]
# Data from : https://www.drivendata.org/competitions/44/dengai-predicting-disease-spread/
#
# Features:
#
# - year
# - weekofyear
# - city – City abbreviations: sj for San Juan and iq for Iquitos
# - week_start_date – Date given in yyyy-mm-dd format
#
# NOAA's GHCN daily climate data weather station measurements
#
# - station_max_temp_c – Maximum temperature
# - station_min_temp_c – Minimum temperature
# - station_avg_temp_c – Average temperature
# - station_precip_mm – Total precipitation
# - station_diur_temp_rng_c – Diurnal temperature range
#
# PERSIANN satellite precipitation measurements (0.25x0.25 degree scale)
#
# - precipitation_amt_mm – Total precipitation
#
# NOAA's NCEP Climate Forecast System Reanalysis measurements (0.5x0.5 degree scale)
#
# - reanalysis_sat_precip_amt_mm – Total precipitation
# - reanalysis_dew_point_temp_k – Mean dew point temperature
# - reanalysis_air_temp_k – Mean air temperature
# - reanalysis_relative_humidity_percent – Mean relative humidity
# - reanalysis_specific_humidity_g_per_kg – Mean specific humidity
# - reanalysis_precip_amt_kg_per_m2 – Total precipitation
# - reanalysis_max_air_temp_k – Maximum air temperature
# - reanalysis_min_air_temp_k – Minimum air temperature
# - reanalysis_avg_temp_k – Average air temperature
# - reanalysis_tdtr_k – Diurnal temperature range
#
# Satellite vegetation - Normalized difference vegetation index (NDVI) - NOAA's CDR Normalized Difference Vegetation Index (0.5x0.5 degree scale) measurements
#
# - ndvi_se – Pixel southeast of city centroid
# - ndvi_sw – Pixel southwest of city centroid
# - ndvi_ne – Pixel northeast of city centroid
# - ndvi_nw – Pixel northwest of city centroid
#
# NDVI = (NIR — VIS)/(NIR + VIS)
#
# "Calculations of NDVI for a given pixel always result in a number that ranges from minus one (-1) to plus one (+1); however, no green leaves gives a value close to zero. A zero means no vegetation and close to +1 (0.8 - 0.9) indicates the highest possible density of green leaves." (3)
#
# ---
#
# NOAA: National Oceanic and Atmosphere Administration
# GHCN: Global Historical Climatology Network
#
# (1) https://www.ncdc.noaa.gov/data-access/land-based-station-data/land-based-datasets/global-historical-climatology-network-ghcn
#
# PERSIANN-CDR: PRECIPITATION ESTIMATION FROM REMOTELY SENSED INFORMATION USING ARTIFICIAL NEURAL NETWORKS
#
# (2) https://climatedataguide.ucar.edu/climate-data/persiann-cdr-precipitation-estimation-remotely-sensed-information-using-artificial
#
#
# (3) https://earthobservatory.nasa.gov/features/MeasuringVegetation/measuring_vegetation_2.php

# %% [markdown]
# ## Load data

# %%
features_train = pd.read_csv('../data/dengue_features_train.csv')
labels_train = pd.read_csv('../data/dengue_labels_train.csv')

features_test = pd.read_csv('../data/dengue_features_test.csv')

# %% [markdown]
# ## Join of train features and labels features

# %%
train_dataset = features_train.merge(labels_train, 
                                    left_on=['city', 'year', 'weekofyear'], 
                                    right_on=['city', 'year', 'weekofyear'],
                                    how='inner')

# %%
train_dataset.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k     ...       \
# 0  0.177617                 12.42             297.572857     ...
# 1  0.155486                 22.82             298.211429     ...
# 2  0.170843                 34.54             298.781429     ...
# 3  0.235886                 15.36             298.987143     ...
# 4  0.247340                  7.52             299.518571     ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                             73.365714                         12.42
# 1                             77.368571                         22.82
# 2                             82.052857                         34.54
# 3                             80.337143                         15.36
# 4                             80.460000                          7.52
#
#    reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 0                              14.012857           2.628571
# 1                              15.372857           2.371429
# 2                              16.848571           2.300000
# 3                              16.672857           2.428571
# 4                              17.210000           3.014286
#
#    station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 0           25.442857                 6.900000                29.4
# 1           26.714286                 6.371429                31.7
# 2           26.714286                 6.485714                32.2
# 3           27.471429                 6.771429                33.3
# 4           28.942857                 9.371429                35.0
#
#    station_min_temp_c  station_precip_mm  total_cases
# 0                20.0               16.0            4
# 1                22.2                8.6            5
# 2                22.8               41.4            4
# 3                23.3                4.0            3
# 4                23.9                5.8            6
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Preeliminary exploration
#
# ### Describe

# %%
train_dataset.describe().T
# Out:
#                                         count         mean        std  \
# year                                   1456.0  2001.031593   5.408314
# weekofyear                             1456.0    26.503434  15.019437
# ndvi_ne                                1262.0     0.142294   0.140531
# ndvi_nw                                1404.0     0.130553   0.119999
# ndvi_se                                1434.0     0.203783   0.073860
# ndvi_sw                                1434.0     0.202305   0.083903
# precipitation_amt_mm                   1443.0    45.760388  43.715537
# reanalysis_air_temp_k                  1446.0   298.701852   1.362420
# reanalysis_avg_temp_k                  1446.0   299.225578   1.261715
# reanalysis_dew_point_temp_k            1446.0   295.246356   1.527810
# reanalysis_max_air_temp_k              1446.0   303.427109   3.234601
# reanalysis_min_air_temp_k              1446.0   295.719156   2.565364
# reanalysis_precip_amt_kg_per_m2        1446.0    40.151819  43.434399
# reanalysis_relative_humidity_percent   1446.0    82.161959   7.153897
# reanalysis_sat_precip_amt_mm           1443.0    45.760388  43.715537
# reanalysis_specific_humidity_g_per_kg  1446.0    16.746427   1.542494
# reanalysis_tdtr_k                      1446.0     4.903754   3.546445
# station_avg_temp_c                     1413.0    27.185783   1.292347
# station_diur_temp_rng_c                1413.0     8.059328   2.128568
# station_max_temp_c                     1436.0    32.452437   1.959318
# station_min_temp_c                     1442.0    22.102150   1.574066
# station_precip_mm                      1434.0    39.326360  47.455314
# total_cases                            1456.0    24.675137  43.596000
#
#                                                min          25%          50%  \
# year                                   1990.000000  1997.000000  2002.000000
# weekofyear                                1.000000    13.750000    26.500000
# ndvi_ne                                  -0.406250     0.044950     0.128817
# ndvi_nw                                  -0.456100     0.049217     0.121429
# ndvi_se                                  -0.015533     0.155087     0.196050
# ndvi_sw                                  -0.063457     0.144209     0.189450
# precipitation_amt_mm                      0.000000     9.800000    38.340000
# reanalysis_air_temp_k                   294.635714   297.658929   298.646429
# reanalysis_avg_temp_k                   294.892857   298.257143   299.289286
# reanalysis_dew_point_temp_k             289.642857   294.118929   295.640714
# reanalysis_max_air_temp_k               297.800000   301.000000   302.400000
# reanalysis_min_air_temp_k               286.900000   293.900000   296.200000
# reanalysis_precip_amt_kg_per_m2           0.000000    13.055000    27.245000
# reanalysis_relative_humidity_percent     57.787143    77.177143    80.301429
# reanalysis_sat_precip_amt_mm              0.000000     9.800000    38.340000
# reanalysis_specific_humidity_g_per_kg    11.715714    15.557143    17.087143
# reanalysis_tdtr_k                         1.357143     2.328571     2.857143
# station_avg_temp_c                       21.400000    26.300000    27.414286
# station_diur_temp_rng_c                   4.528571     6.514286     7.300000
# station_max_temp_c                       26.700000    31.100000    32.800000
# station_min_temp_c                       14.700000    21.100000    22.200000
# station_precip_mm                         0.000000     8.700000    23.850000
# total_cases                               0.000000     5.000000    12.000000
#
#                                                75%          max
# year                                   2005.000000  2010.000000
# weekofyear                               39.250000    53.000000
# ndvi_ne                                   0.248483     0.508357
# ndvi_nw                                   0.216600     0.454429
# ndvi_se                                   0.248846     0.538314
# ndvi_sw                                   0.246982     0.546017
# precipitation_amt_mm                     70.235000   390.600000
# reanalysis_air_temp_k                   299.833571   302.200000
# reanalysis_avg_temp_k                   300.207143   302.928571
# reanalysis_dew_point_temp_k             296.460000   298.450000
# reanalysis_max_air_temp_k               305.500000   314.000000
# reanalysis_min_air_temp_k               297.900000   299.900000
# reanalysis_precip_amt_kg_per_m2          52.200000   570.500000
# reanalysis_relative_humidity_percent     86.357857    98.610000
# reanalysis_sat_precip_amt_mm             70.235000   390.600000
# reanalysis_specific_humidity_g_per_kg    17.978214    20.461429
# reanalysis_tdtr_k                         7.625000    16.028571
# station_avg_temp_c                       28.157143    30.800000
# station_diur_temp_rng_c                   9.566667    15.800000
# station_max_temp_c                       33.900000    42.200000
# station_min_temp_c                       23.300000    25.600000
# station_precip_mm                        53.900000   543.300000
# total_cases                              28.000000   461.000000

# %% [markdown]
# Here, we see that there are some missing values. *ndvi_ne* is the feature with the higher number of missing values. In respect to temeperature features, it seems that some of them are expressed different units.

# %% [markdown]
# ### Line plot of total_cases for both cities

# %%
train_dataset['week_start_date'] = pd.to_datetime(train_dataset['week_start_date'])

du.show_lineplot(train_dataset, xvalue='week_start_date', yvalue='total_cases', hue='city')

# %% [markdown]
# The evolution of the number of total cases en both cities is quite diferent. For this reason we explore the data of both cities separately.

# %% [markdown]
# ### Boxplots

# %%
du.show_boxplot(train_dataset[train_dataset['city']=='sj'], exclude=['year'])
# Out:
# 20190422 - 15:M:26: show_bloxplot: omiting city
# 20190422 - 15:M:26: show_bloxplot: omiting year
# 20190422 - 15:M:26: show_bloxplot: omiting week_start_date

# %%
du.show_boxplot(train_dataset[train_dataset['city']=='iq'], exclude=['year'])
# Out:
# 20190422 - 15:M:27: show_bloxplot: omiting city
# 20190422 - 15:M:27: show_bloxplot: omiting year
# 20190422 - 15:M:27: show_bloxplot: omiting week_start_date

# %%
# Conversion kelvin to celsius

train_dataset = dutils.temperature_conversion(train_dataset)
du.show_boxplot(train_dataset, exclude=['year'])
# Out:
# 20190422 - 15:M:28: temperature conversion: kelvin to celsius reanalysis_air_temp_k to reanalysis_air_temp_c
# 20190422 - 15:M:28: temperature conversion: kelvin to celsius reanalysis_dew_point_temp_k to reanalysis_dew_point_temp_c
# 20190422 - 15:M:28: temperature conversion: kelvin to celsius reanalysis_max_air_temp_k to reanalysis_max_air_temp_c
# 20190422 - 15:M:28: temperature conversion: kelvin to celsius reanalysis_min_air_temp_k to reanalysis_min_air_temp_c
# 20190422 - 15:M:28: temperature conversion: kelvin to celsius reanalysis_avg_temp_k to reanalysis_avg_temp_c
# 20190422 - 15:M:28: show_bloxplot: omiting city
# 20190422 - 15:M:28: show_bloxplot: omiting year
# 20190422 - 15:M:28: show_bloxplot: omiting week_start_date

# %% [markdown]
# **NOTE:** reanalysis_tdtr_c takes extreme temperature values, I wil remove that feature at the moment.

# %% [markdown]
# ### Correlation matrix for each city
#
# ####  San Juan

# %%
du.show_heatmap(train_dataset[train_dataset['city']=='sj'], exclude = ['city'])

# %% [markdown]
# #### Iquitos

# %%
du.show_heatmap(train_dataset[train_dataset['city']=='iq'], exclude = ['city'])

# %% [markdown]
# - For both cities, the label (total_cases) doesn't show correlation with other features
# - There is colineality among features, for example temeperature features. It will be necesary some feature selection to avoid this colineality.
# - In the next plot we can see the relationship betwen the features and the label:

# %%
du.show_feature_correlation(train_dataset[train_dataset['city']=='sj'], 
                            label = 'total_cases', 
                            title= 'Feature vs Label correlation (San Juan)', 
                            exclude = ['city'])

# %%
du.show_feature_correlation(train_dataset[train_dataset['city']=='iq'], 
                            label = 'total_cases', 
                            title= 'Feature vs Label correlation (Iquitos)', 
                            exclude = ['city'])

# %% [markdown]
# ### Feature analysis
#
# - Missing values
# - Variability
# - Correlation with label

# %%
import seaborn as sns

def get_feature_analysis(df):
    
    features_analysis = pd.DataFrame()

    for city in df.loc[:,'city'].unique():

        temp = pd.DataFrame()
        df_city = df.loc[df.loc[:,'city']==city,:]

        # number of missing values
        describe_df = pd.DataFrame(df_city.describe().T)
        describe_df.loc[:,'count'].max()

        max_number_of_rows = describe_df.loc[:,'count'].max()
        number_of_values   = describe_df.loc[:,'count']

        temp.loc[:,'missing_values'] = max_number_of_rows - number_of_values

        # feature variability

        temp['variance'] = df_city.var(axis=0)
        temp['cv'] =  df_city.std(axis=0) / df_city.mean(axis=0)

        # correlation with label
        if 'total_cases' in df_city.columns:
            temp['label_corr'] = np.abs(df_city.corr()['total_cases'])

        temp['city'] = city

        features_analysis = pd.concat([features_analysis, temp], axis=0)
        
    return features_analysis
    

def get_last_weeks_data(df):
    
    train_dataset_lastweeks = pd.DataFrame()

    for city in df.loc[:,'city'].unique():

        temp = df.loc[df.loc[:,'city']==city,:]

        climate_variables = temp.columns.copy()
        
        if 'total_cases' in climate_variables:
            climate_variables = climate_variables.drop('total_cases')   
        
        
        climate_variables = climate_variables.drop(['weekofyear', 'city', 'week_start_date', 'year'])

        for j, climate_variable in enumerate(climate_variables):
            temp.loc[:,climate_variable] = (temp.sort_values(['city', 'year', 'weekofyear'], 
                                                       ascending=True).loc[:,climate_variable]
                                           .rolling(window=12).median())


        train_dataset_lastweeks = pd.concat([train_dataset_lastweeks, temp], axis=0)    
    
    return train_dataset_lastweeks


    
features_analysis = get_feature_analysis(train_dataset)

features_analysis.sort_values('label_corr', ascending=False)

features_analysis.loc[features_analysis['city'] == 'sj',:].sort_values('label_corr', ascending=False)
# Out:
#                                        missing_values     variance        cv  \
# total_cases                                       0.0  2640.045440  1.503234
# weekofyear                                        0.0   225.657744  0.566796
# year                                              0.0    27.165734  0.002608
# reanalysis_specific_humidity_g_per_kg             6.0     2.436481  0.094302
# reanalysis_dew_point_temp_c                       6.0     2.464722  0.071493
# station_avg_temp_c                                6.0     2.003565  0.052412
# reanalysis_max_air_temp_c                         6.0     1.584896  0.044566
# station_max_temp_c                                6.0     2.949108  0.054331
# reanalysis_min_air_temp_c                         6.0     1.676261  0.053607
# reanalysis_air_temp_c                             6.0     1.528757  0.047530
# station_min_temp_c                                6.0     2.268869  0.066648
# reanalysis_avg_temp_c                             6.0     1.485077  0.046643
# reanalysis_relative_humidity_percent              6.0    11.488627  0.043141
# reanalysis_precip_amt_kg_per_m2                   6.0  1269.358301  1.169459
# ndvi_nw                                          49.0     0.008552  1.370684
# reanalysis_tdtr_k                                 6.0     0.248893  0.198267
# reanalysis_sat_precip_amt_mm                      9.0  1989.707444  1.257545
# precipitation_amt_mm                              9.0  1989.707444  1.257545
# station_precip_mm                                 6.0   860.003180  1.094840
# ndvi_ne                                         191.0     0.011482  1.849862
# station_diur_temp_rng_c                           6.0     0.698884  0.123716
# ndvi_se                                          19.0     0.003268  0.321783
# ndvi_sw                                          19.0     0.003144  0.337881
#
#                                        label_corr city
# total_cases                              1.000000   sj
# weekofyear                               0.287134   sj
# year                                     0.212690   sj
# reanalysis_specific_humidity_g_per_kg    0.207947   sj
# reanalysis_dew_point_temp_c              0.203774   sj
# station_avg_temp_c                       0.196617   sj
# reanalysis_max_air_temp_c                0.194532   sj
# station_max_temp_c                       0.189901   sj
# reanalysis_min_air_temp_c                0.187943   sj
# reanalysis_air_temp_c                    0.181917   sj
# station_min_temp_c                       0.177012   sj
# reanalysis_avg_temp_c                    0.175267   sj
# reanalysis_relative_humidity_percent     0.144045   sj
# reanalysis_precip_amt_kg_per_m2          0.107457   sj
# ndvi_nw                                  0.075307   sj
# reanalysis_tdtr_k                        0.067600   sj
# reanalysis_sat_precip_amt_mm             0.060211   sj
# precipitation_amt_mm                     0.060211   sj
# station_precip_mm                        0.051759   sj
# ndvi_ne                                  0.037639   sj
# station_diur_temp_rng_c                  0.034630   sj
# ndvi_se                                  0.001113   sj
# ndvi_sw                                  0.000333   sj

# %%
features_analysis.loc[features_analysis['city'] == 'iq',:].sort_values('label_corr', ascending=False)
# Out:
#                                        missing_values     variance        cv  \
# total_cases                                       0.0   115.895524  1.422992
# reanalysis_specific_humidity_g_per_kg             4.0     2.090248  0.084567
# reanalysis_dew_point_temp_c                       4.0     2.008539  0.063431
# reanalysis_min_air_temp_c                         4.0     2.765799  0.084348
# station_min_temp_c                                8.0     1.588423  0.059459
# year                                              0.0     8.516378  0.001456
# reanalysis_tdtr_k                                 4.0     5.995273  0.265948
# reanalysis_relative_humidity_percent              4.0    57.515374  0.085559
# station_avg_temp_c                               37.0     0.849657  0.033481
# reanalysis_precip_amt_kg_per_m2                   4.0  2528.737597  0.872881
# reanalysis_air_temp_c                             4.0     1.371234  0.047371
# reanalysis_sat_precip_amt_mm                      4.0  1240.377599  0.548192
# precipitation_amt_mm                              4.0  1240.377599  0.548192
# reanalysis_avg_temp_c                             4.0     1.774419  0.051267
# station_max_temp_c                               14.0     1.756316  0.038973
# station_diur_temp_rng_c                          37.0     2.357748  0.145322
# reanalysis_max_air_temp_c                         4.0     5.678595  0.070227
# station_precip_mm                                16.0  4000.051232  1.012466
# ndvi_se                                           3.0     0.005984  0.309259
# ndvi_sw                                           3.0     0.007455  0.323658
# ndvi_ne                                           3.0     0.006621  0.308373
# weekofyear                                        0.0   225.884378  0.567067
# ndvi_nw                                           3.0     0.005891  0.321428
#
#                                        label_corr city
# total_cases                              1.000000   iq
# reanalysis_specific_humidity_g_per_kg    0.236476   iq
# reanalysis_dew_point_temp_c              0.230401   iq
# reanalysis_min_air_temp_c                0.214514   iq
# station_min_temp_c                       0.211702   iq
# year                                     0.179451   iq
# reanalysis_tdtr_k                        0.134425   iq
# reanalysis_relative_humidity_percent     0.130083   iq
# station_avg_temp_c                       0.113070   iq
# reanalysis_precip_amt_kg_per_m2          0.101171   iq
# reanalysis_air_temp_c                    0.097098   iq
# reanalysis_sat_precip_amt_mm             0.090171   iq
# precipitation_amt_mm                     0.090171   iq
# reanalysis_avg_temp_c                    0.079872   iq
# station_max_temp_c                       0.075279   iq
# station_diur_temp_rng_c                  0.058230   iq
# reanalysis_max_air_temp_c                0.056474   iq
# station_precip_mm                        0.042976   iq
# ndvi_se                                  0.041067   iq
# ndvi_sw                                  0.032999   iq
# ndvi_ne                                  0.020215   iq
# weekofyear                               0.011850   iq
# ndvi_nw                                  0.009586   iq

# %% [markdown]
# Correlation among features and the label is quite low for both cities and for all features. For San Juan, variables more interesting could be:
#
# - reanalysis_specific_humidity_g_per_kg,
# - reanalysis_dew_point_temp_c
# - station_avg_temp_c
# - reanalysis_max_air_temp_c
#
# Iquitos:
#
# - reanalysis_specific_humidity_g_per_kg
# - reanalysis_dew_point_temp_c
# - reanalysis_min_air_temp_c
# - station_min_temp_c
#
# But not one of these variables reach a correlation higher than 0.3.
#
# Then, I notice that, the weather of the previous weeks could affect to the number of cases. So I performed the same feature analysis using weather data of the last weeks:

# %%
train_dataset = train_dataset.fillna(method='ffill')
train_dataset_lastweeks = get_last_weeks_data(train_dataset)
    
train_dataset_lastweeks = train_dataset_lastweeks.loc[train_dataset_lastweeks.loc[:,'week_start_date']  >= '2002-01-01',:]
train_dataset_lastweeks.head()
# Out:
#     city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 607   sj  2002           1      2002-01-01  0.041575  0.089254  0.211736
# 608   sj  2002           2      2002-01-08  0.041575  0.105088  0.212471
# 609   sj  2002           3      2002-01-15  0.057075  0.089254  0.201129
# 610   sj  2002           4      2002-01-22  0.057075  0.089254  0.196857
# 611   sj  2002           5      2002-01-29  0.057075  0.089254  0.196857
#
#       ndvi_sw  precipitation_amt_mm  reanalysis_precip_amt_kg_per_m2  \
# 607  0.170886                41.805                           23.795
# 608  0.178294                35.355                           20.405
# 609  0.168923                29.520                           18.380
# 610  0.167051                29.520                           15.830
# 611  0.167051                20.220                           13.500
#
#              ...            station_diur_temp_rng_c  station_max_temp_c  \
# 607          ...                           6.228571               31.10
# 608          ...                           6.228571               30.55
# 609          ...                           6.228571               30.00
# 610          ...                           6.242857               30.00
# 611          ...                           5.935714               29.70
#
#      station_min_temp_c  station_precip_mm  total_cases  \
# 607                22.8              40.35           37
# 608                22.8              30.80           38
# 609                22.5              30.80           34
# 610                22.2              30.80           26
# 611                22.2              31.50           19
#
#      reanalysis_air_temp_c  reanalysis_dew_point_temp_c  \
# 607              26.051429                    22.509286
# 608              25.856429                    22.385714
# 609              25.782857                    22.267857
# 610              25.580714                    21.932857
# 611              25.352143                    21.511429
#
#      reanalysis_max_air_temp_c  reanalysis_min_air_temp_c  \
# 607                      29.00                      24.10
# 608                      28.40                      24.00
# 609                      27.85                      23.80
# 610                      27.75                      23.80
# 611                      27.60                      23.65
#
#      reanalysis_avg_temp_c
# 607              26.117857
# 608              25.925000
# 609              25.857143
# 610              25.610714
# 611              25.385714
#
# [5 rows x 25 columns]

# %%
features_analysis_lastweeks = get_feature_analysis(train_dataset_lastweeks)
features_analysis_lastweeks = features_analysis_lastweeks.sort_values('label_corr', ascending=False)
features_analysis_lastweeks = features_analysis_lastweeks.loc[features_analysis_lastweeks['label_corr'] > 0.2,:]
features_analysis_lastweeks
# Out:
#                                        missing_values    variance        cv  \
# total_cases                                       0.0  125.136742  1.262618
# total_cases                                       0.0  637.366688  1.289547
# station_min_temp_c                                0.0    1.610118  0.055975
# reanalysis_air_temp_c                             0.0    1.317136  0.043497
# reanalysis_avg_temp_c                             0.0    1.241636  0.042025
# reanalysis_max_air_temp_c                         0.0    1.254429  0.039189
# station_avg_temp_c                                0.0    1.678870  0.048086
# reanalysis_min_air_temp_c                         0.0    1.164410  0.044112
# reanalysis_specific_humidity_g_per_kg             0.0    1.822803  0.080663
# reanalysis_dew_point_temp_c                       0.0    1.736524  0.059461
# precipitation_amt_mm                              0.0  415.196789  0.813443
# reanalysis_sat_precip_amt_mm                      0.0  415.196789  0.813443
# station_max_temp_c                                0.0    2.232354  0.047676
# reanalysis_precip_amt_kg_per_m2                   0.0   60.790854  0.414450
# station_precip_mm                                 0.0  108.859720  0.476092
# ndvi_nw                                           0.0    0.001575  3.128868
# weekofyear                                        0.0  230.722681  0.593370
# reanalysis_tdtr_k                                 0.0    0.067983  0.098055
# reanalysis_avg_temp_c                             0.0    0.699857  0.032182
# ndvi_ne                                           0.0    0.001266  4.054333
# reanalysis_air_temp_c                             0.0    0.530566  0.029475
# station_max_temp_c                                0.0    0.801657  0.026396
# ndvi_se                                           0.0    0.000772  0.157521
# reanalysis_max_air_temp_c                         0.0    2.401756  0.045882
# station_diur_temp_rng_c                           0.0    1.103597  0.102159
# ndvi_sw                                           0.0    0.001631  0.154116
#
#                                        label_corr city
# total_cases                              1.000000   iq
# total_cases                              1.000000   sj
# station_min_temp_c                       0.532821   sj
# reanalysis_air_temp_c                    0.532760   sj
# reanalysis_avg_temp_c                    0.527611   sj
# reanalysis_max_air_temp_c                0.525257   sj
# station_avg_temp_c                       0.511224   sj
# reanalysis_min_air_temp_c                0.508540   sj
# reanalysis_specific_humidity_g_per_kg    0.501592   sj
# reanalysis_dew_point_temp_c              0.496224   sj
# precipitation_amt_mm                     0.476694   sj
# reanalysis_sat_precip_amt_mm             0.476694   sj
# station_max_temp_c                       0.462138   sj
# reanalysis_precip_amt_kg_per_m2          0.353305   sj
# station_precip_mm                        0.329027   sj
# ndvi_nw                                  0.318320   sj
# weekofyear                               0.309310   sj
# reanalysis_tdtr_k                        0.302188   sj
# reanalysis_avg_temp_c                    0.251376   iq
# ndvi_ne                                  0.239548   sj
# reanalysis_air_temp_c                    0.225350   iq
# station_max_temp_c                       0.221803   iq
# ndvi_se                                  0.213748   sj
# reanalysis_max_air_temp_c                0.212166   iq
# station_diur_temp_rng_c                  0.209953   iq
# ndvi_sw                                  0.207113   iq

# %% [markdown]
# ### Testing dataset

# %%
features_test.describe().T
# Out:
#                                        count         mean        std  \
# year                                   416.0  2010.766827   1.434835
# weekofyear                             416.0    26.439904  14.978257
# ndvi_ne                                373.0     0.126050   0.164353
# ndvi_nw                                405.0     0.126803   0.141420
# ndvi_se                                415.0     0.207702   0.079102
# ndvi_sw                                415.0     0.201721   0.092028
# precipitation_amt_mm                   414.0    38.354324  35.171126
# reanalysis_air_temp_k                  414.0   298.818295   1.469501
# reanalysis_avg_temp_k                  414.0   299.353071   1.306233
# reanalysis_dew_point_temp_k            414.0   295.419179   1.523099
# reanalysis_max_air_temp_k              414.0   303.623430   3.101817
# reanalysis_min_air_temp_k              414.0   295.743478   2.761109
# reanalysis_precip_amt_kg_per_m2        414.0    42.171135  48.909514
# reanalysis_relative_humidity_percent   414.0    82.499810   7.378243
# reanalysis_sat_precip_amt_mm           414.0    38.354324  35.171126
# reanalysis_specific_humidity_g_per_kg  414.0    16.927088   1.557868
# reanalysis_tdtr_k                      414.0     5.124569   3.542870
# station_avg_temp_c                     404.0    27.369587   1.232608
# station_diur_temp_rng_c                404.0     7.810991   2.449718
# station_max_temp_c                     413.0    32.534625   1.920429
# station_min_temp_c                     407.0    22.368550   1.731437
# station_precip_mm                      411.0    34.278589  34.655966
#
#                                                min          25%          50%  \
# year                                   2008.000000  2010.000000  2011.000000
# weekofyear                                1.000000    13.750000    26.000000
# ndvi_ne                                  -0.463400    -0.001500     0.110100
# ndvi_nw                                  -0.211800     0.015975     0.088700
# ndvi_se                                   0.006200     0.148670     0.204171
# ndvi_sw                                  -0.014671     0.134079     0.186471
# precipitation_amt_mm                      0.000000     8.175000    31.455000
# reanalysis_air_temp_k                   294.554286   297.751429   298.547143
# reanalysis_avg_temp_k                   295.235714   298.323214   299.328571
# reanalysis_dew_point_temp_k             290.818571   294.335714   295.825000
# reanalysis_max_air_temp_k               298.200000   301.425000   302.750000
# reanalysis_min_air_temp_k               286.200000   293.500000   296.300000
# reanalysis_precip_amt_kg_per_m2           0.000000     9.430000    25.850000
# reanalysis_relative_humidity_percent     64.920000    77.397143    80.330000
# reanalysis_sat_precip_amt_mm              0.000000     8.175000    31.455000
# reanalysis_specific_humidity_g_per_kg    12.537143    15.792857    17.337143
# reanalysis_tdtr_k                         1.485714     2.446429     2.914286
# station_avg_temp_c                       24.157143    26.514286    27.483333
# station_diur_temp_rng_c                   4.042857     5.928571     6.642857
# station_max_temp_c                       27.200000    31.100000    32.800000
# station_min_temp_c                       14.200000    21.200000    22.200000
# station_precip_mm                         0.000000     9.100000    23.600000
#
#                                                75%          max
# year                                   2012.000000  2013.000000
# weekofyear                               39.000000    53.000000
# ndvi_ne                                   0.263329     0.500400
# ndvi_nw                                   0.242400     0.649000
# ndvi_se                                   0.254871     0.453043
# ndvi_sw                                   0.253243     0.529043
# precipitation_amt_mm                     57.772500   169.340000
# reanalysis_air_temp_k                   300.240357   301.935714
# reanalysis_avg_temp_k                   300.521429   303.328571
# reanalysis_dew_point_temp_k             296.643571   297.794286
# reanalysis_max_air_temp_k               305.800000   314.100000
# reanalysis_min_air_temp_k               298.275000   299.700000
# reanalysis_precip_amt_kg_per_m2          56.475000   301.400000
# reanalysis_relative_humidity_percent     88.328929    97.982857
# reanalysis_sat_precip_amt_mm             57.772500   169.340000
# reanalysis_specific_humidity_g_per_kg    18.174643    19.598571
# reanalysis_tdtr_k                         8.171429    14.485714
# station_avg_temp_c                       28.319048    30.271429
# station_diur_temp_rng_c                   9.812500    14.725000
# station_max_temp_c                       33.900000    38.400000
# station_min_temp_c                       23.300000    26.700000
# station_precip_mm                        47.750000   212.000000

# %% [markdown]
# ### Density plots
#
# These plots confirms the observed in previous analysis. Cities should be studied by saparate. Weather and total_cases are diferent in both cities.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#features = train_dataset.columns.drop(['week_start_date'])

fig = plt.figure(figsize=(20, 20))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i, column in enumerate(features):

    ax = fig.add_subplot(5, 5, i+1)

    data_sj = train_dataset[train_dataset['city']=='sj'][column]
    data_iq = train_dataset[train_dataset['city']=='iq'][column]
    
    sns.distplot(data_sj, hist=False, kde=True, bins=int(180/5), color = 'salmon', 
             hist_kws={'edgecolor':'black'}, kde_kws={'linewidth': 3})
    
    sns.distplot(data_iq, hist=False, kde=True, bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'}, kde_kws={'linewidth': 3})

# %% [markdown]
# ### Scatter plots
#
# Here, I plot the scatter plot of each feature vs total_cases for both cities. (Blue = san juan, Salmon = Iquitos)

# %%
features = train_dataset.columns.drop(['city', 'total_cases'])

fig = plt.figure(figsize=(30, 30))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i, column in enumerate(features):

    ax = fig.add_subplot(6, 4, i+1)
    
    sns.scatterplot(x=column, y="total_cases", 
                    hue='city', data=train_dataset, 
                    palette = dict(iq="salmon", 
                                   sj="c"))

# %% [markdown]
# ## Add new variables

# %%
## Add month of the year

train_dataset['week_start_date'] = pd.to_datetime(train_dataset['week_start_date'])
train_dataset['monthofyear'] = train_dataset['week_start_date'].apply(lambda x: x.month)


# High correlation between ndvi_nw-ndvi-ne and ndvi-sw-ndvi-se
# Add the mean of each pair that indicates the level of vegetation in the north and south of both cities.

# Features engineering

train_dataset['ndvi_north'] = train_dataset[['ndvi_nw', 'ndvi_ne']].mean(axis=1)
train_dataset['ndvi_south'] = train_dataset[['ndvi_sw', 'ndvi_se']].mean(axis=1)

#Remove feature

train_dataset = train_dataset.drop(['ndvi_sw', 'ndvi_nw', 'ndvi_ne', 'ndvi_se', 'week_start_date'], axis=1)

# %%
train_dataset.head()
# Out:
#   city  year  weekofyear  precipitation_amt_mm  \
# 0   sj  1990          18                 12.42
# 1   sj  1990          19                 22.82
# 2   sj  1990          20                 34.54
# 3   sj  1990          21                 15.36
# 4   sj  1990          22                  7.52
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# 1                            17.94                             77.368571
# 2                            26.10                             82.052857
# 3                            13.90                             80.337143
# 4                            12.20                             80.460000
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# 0                         12.42                              14.012857
# 1                         22.82                              15.372857
# 2                         34.54                              16.848571
# 3                         15.36                              16.672857
# 4                          7.52                              17.210000
#
#    reanalysis_tdtr_k  station_avg_temp_c     ...      station_precip_mm  \
# 0           2.628571           25.442857     ...                   16.0
# 1           2.371429           26.714286     ...                    8.6
# 2           2.300000           26.714286     ...                   41.4
# 3           2.428571           27.471429     ...                    4.0
# 4           3.014286           28.942857     ...                    5.8
#
#    total_cases  reanalysis_air_temp_c  reanalysis_dew_point_temp_c  \
# 0            4              24.422857                    19.264286
# 1            5              25.061429                    20.801429
# 2            4              25.631429                    22.284286
# 3            3              25.837143                    22.160000
# 4            6              26.368571                    22.671429
#
#    reanalysis_max_air_temp_c  reanalysis_min_air_temp_c  \
# 0                      26.65                      22.75
# 1                      27.75                      23.25
# 2                      27.35                      24.15
# 3                      28.25                      23.85
# 4                      28.75                      24.35
#
#    reanalysis_avg_temp_c  monthofyear  ndvi_north  ndvi_south
# 0              24.592857            4    0.113162    0.188050
# 1              25.292857            5    0.156037    0.158921
# 2              25.728571            5    0.102608    0.164021
# 3              26.078571            5    0.186850    0.231721
# 4              26.514286            5    0.229200    0.249270
#
# [5 rows x 23 columns]
