# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

import dengue_utils as dutils
import dsutils as du

# %% [markdown]
# ## Features description

# %% [markdown]
# Data from : https://www.drivendata.org/competitions/44/dengai-predicting-disease-spread/
#
# Features:
#
# - year
# - weekofyear
# - city – City abbreviations: sj for San Juan and iq for Iquitos
# - week_start_date – Date given in yyyy-mm-dd format
#
# NOAA's GHCN daily climate data weather station measurements
#
# - station_max_temp_c – Maximum temperature
# - station_min_temp_c – Minimum temperature
# - station_avg_temp_c – Average temperature
# - station_precip_mm – Total precipitation
# - station_diur_temp_rng_c – Diurnal temperature range
#
# PERSIANN satellite precipitation measurements (0.25x0.25 degree scale)
#
# - precipitation_amt_mm – Total precipitation
#
# NOAA's NCEP Climate Forecast System Reanalysis measurements (0.5x0.5 degree scale)
#
# - reanalysis_sat_precip_amt_mm – Total precipitation
# - reanalysis_dew_point_temp_k – Mean dew point temperature
# - reanalysis_air_temp_k – Mean air temperature
# - reanalysis_relative_humidity_percent – Mean relative humidity
# - reanalysis_specific_humidity_g_per_kg – Mean specific humidity
# - reanalysis_precip_amt_kg_per_m2 – Total precipitation
# - reanalysis_max_air_temp_k – Maximum air temperature
# - reanalysis_min_air_temp_k – Minimum air temperature
# - reanalysis_avg_temp_k – Average air temperature
# - reanalysis_tdtr_k – Diurnal temperature range
#
# Satellite vegetation - Normalized difference vegetation index (NDVI) - NOAA's CDR Normalized Difference Vegetation Index (0.5x0.5 degree scale) measurements
#
# - ndvi_se – Pixel southeast of city centroid
# - ndvi_sw – Pixel southwest of city centroid
# - ndvi_ne – Pixel northeast of city centroid
# - ndvi_nw – Pixel northwest of city centroid
#
# NDVI = (NIR — VIS)/(NIR + VIS)
#
# "Calculations of NDVI for a given pixel always result in a number that ranges from minus one (-1) to plus one (+1); however, no green leaves gives a value close to zero. A zero means no vegetation and close to +1 (0.8 - 0.9) indicates the highest possible density of green leaves." (3)
#
# ---
#
# NOAA: National Oceanic and Atmosphere Administration
# GHCN: Global Historical Climatology Network
#
# (1) https://www.ncdc.noaa.gov/data-access/land-based-station-data/land-based-datasets/global-historical-climatology-network-ghcn
#
# PERSIANN-CDR: PRECIPITATION ESTIMATION FROM REMOTELY SENSED INFORMATION USING ARTIFICIAL NEURAL NETWORKS
#
# (2) https://climatedataguide.ucar.edu/climate-data/persiann-cdr-precipitation-estimation-remotely-sensed-information-using-artificial
#
#
# (3) https://earthobservatory.nasa.gov/features/MeasuringVegetation/measuring_vegetation_2.php

# %% [markdown]
# ## Load data

# %%
# Load dataset

features_train = pd.read_csv('../data/dengue_features_train.csv')
labels_train   = pd.read_csv('../data/dengue_labels_train.csv')

features_test = pd.read_csv('../data/dengue_features_test.csv')

dengue_dataset = pd.concat([features_train, features_test], axis = 0)

# Join train labes and features
dengue_dataset_labeled = dengue_dataset.merge(labels_train, 
                                           left_on = ['city', 'year', 'weekofyear'], 
                                           right_on = ['city', 'year', 'weekofyear'],
                                           how = 'outer')

# %%
dengue_dataset_labeled.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                             73.365714                         12.42
# 1                             77.368571                         22.82
# 2                             82.052857                         34.54
# 3                             80.337143                         15.36
# 4                             80.460000                          7.52
#
#    reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 0                              14.012857           2.628571
# 1                              15.372857           2.371429
# 2                              16.848571           2.300000
# 3                              16.672857           2.428571
# 4                              17.210000           3.014286
#
#    station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 0           25.442857                 6.900000                29.4
# 1           26.714286                 6.371429                31.7
# 2           26.714286                 6.485714                32.2
# 3           27.471429                 6.771429                33.3
# 4           28.942857                 9.371429                35.0
#
#    station_min_temp_c  station_precip_mm  total_cases
# 0                20.0               16.0          4.0
# 1                22.2                8.6          5.0
# 2                22.8               41.4          4.0
# 3                23.3                4.0          3.0
# 4                23.9                5.8          6.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Preeliminary exploration

# %% [markdown]
# ### Describe

# %%
dengue_dataset_labeled.describe().T
# Out:
#                                         count         mean        std  \
# year                                   1872.0  2003.194979   6.292268
# weekofyear                             1872.0    26.489316  15.006319
# ndvi_ne                                1635.0     0.138588   0.146413
# ndvi_nw                                1809.0     0.129713   0.125082
# ndvi_se                                1849.0     0.204663   0.075064
# ndvi_sw                                1849.0     0.202174   0.085768
# precipitation_amt_mm                   1857.0    44.109278  42.065868
# reanalysis_air_temp_k                  1860.0   298.727770   1.387410
# reanalysis_avg_temp_k                  1860.0   299.253955   1.272510
# reanalysis_dew_point_temp_k            1860.0   295.284823   1.528046
# reanalysis_max_air_temp_k              1860.0   303.470806   3.205739
# reanalysis_min_air_temp_k              1860.0   295.724570   2.609461
# reanalysis_precip_amt_kg_per_m2        1860.0    40.601280  44.705280
# reanalysis_relative_humidity_percent   1860.0    82.237158   7.203803
# reanalysis_sat_precip_amt_mm           1857.0    44.109278  42.065868
# reanalysis_specific_humidity_g_per_kg  1860.0    16.786638   1.547336
# reanalysis_tdtr_k                      1860.0     4.952903   3.545887
# station_avg_temp_c                     1817.0    27.226651   1.281254
# station_diur_temp_rng_c                1817.0     8.004112   2.205734
# station_max_temp_c                     1849.0    32.470795   1.950483
# station_min_temp_c                     1849.0    22.160790   1.613325
# station_precip_mm                      1845.0    38.201897  44.961360
# total_cases                            1456.0    24.675137  43.596000
#
#                                                min          25%          50%  \
# year                                   1990.000000  1999.000000  2004.000000
# weekofyear                                1.000000    13.750000    26.000000
# ndvi_ne                                  -0.463400     0.035300     0.127317
# ndvi_nw                                  -0.456100     0.041225     0.115200
# ndvi_se                                  -0.015533     0.153457     0.197029
# ndvi_sw                                  -0.063457     0.141014     0.188229
# precipitation_amt_mm                      0.000000     9.430000    36.640000
# reanalysis_air_temp_k                   294.554286   297.678929   298.617143
# reanalysis_avg_temp_k                   294.892857   298.276786   299.300000
# reanalysis_dew_point_temp_k             289.642857   294.164643   295.667143
# reanalysis_max_air_temp_k               297.800000   301.000000   302.600000
# reanalysis_min_air_temp_k               286.200000   293.800000   296.200000
# reanalysis_precip_amt_kg_per_m2           0.000000    12.492500    27.080000
# reanalysis_relative_humidity_percent     57.787143    77.214643    80.307143
# reanalysis_sat_precip_amt_mm              0.000000     9.430000    36.640000
# reanalysis_specific_humidity_g_per_kg    11.715714    15.590714    17.137143
# reanalysis_tdtr_k                         1.357143     2.357143     2.871429
# station_avg_temp_c                       21.400000    26.328571    27.433333
# station_diur_temp_rng_c                   4.042857     6.357143     7.200000
# station_max_temp_c                       26.700000    31.100000    32.800000
# station_min_temp_c                       14.200000    21.100000    22.200000
# station_precip_mm                         0.000000     8.800000    23.800000
# total_cases                               0.000000     5.000000    12.000000
#
#                                                75%          max
# year                                   2008.000000  2013.000000
# weekofyear                               39.000000    53.000000
# ndvi_ne                                   0.252225     0.508357
# ndvi_nw                                   0.223360     0.649000
# ndvi_se                                   0.250857     0.538314
# ndvi_sw                                   0.248086     0.546017
# precipitation_amt_mm                     67.500000   390.600000
# reanalysis_air_temp_k                   299.891429   302.200000
# reanalysis_avg_temp_k                   300.271429   303.328571
# reanalysis_dew_point_temp_k             296.502857   298.450000
# reanalysis_max_air_temp_k               305.500000   314.100000
# reanalysis_min_air_temp_k               298.000000   299.900000
# reanalysis_precip_amt_kg_per_m2          53.125000   570.500000
# reanalysis_relative_humidity_percent     86.799286    98.610000
# reanalysis_sat_precip_amt_mm             67.500000   390.600000
# reanalysis_specific_humidity_g_per_kg    18.028929    20.461429
# reanalysis_tdtr_k                         7.757143    16.028571
# station_avg_temp_c                       28.200000    30.800000
# station_diur_temp_rng_c                   9.625000    15.800000
# station_max_temp_c                       33.900000    42.200000
# station_min_temp_c                       23.300000    26.700000
# station_precip_mm                        51.500000   543.300000
# total_cases                              28.000000   461.000000

# %% [markdown]
# ### Missing values

# %%
# Incluir label
dengue_dataset_labeled = dengue_dataset.merge(labels_train, 
                                           left_on = ['city', 'year', 'weekofyear'], 
                                           right_on = ['city', 'year', 'weekofyear'],
                                           how = 'outer')

# Creamos un dataframe que contenga el número de missing values para cada columna

# Número de missing values: dengue_dataset_labeled.shape[0] - dengue_dataset_labeled.count()

# shape[0] - contiene en número de filas del dataframe
# count() - el número de valores distintos a null para cada columna

df_count_dengue = pd.DataFrame(dengue_dataset_labeled.shape[0] - dengue_dataset_labeled.count(), 
                               columns=['missing_values'])
df_count_dengue['missing_values_per'] = np.round((df_count_dengue['missing_values'] * 100) / dengue_dataset_labeled.shape[0], 2)

# Solo las filas con missing_value > 0
df_count_dengue = df_count_dengue.loc[df_count_dengue['missing_values']>0,]

# Ordenamos el resultado
df_count_dengue = df_count_dengue.sort_values(by='missing_values')

df_count_dengue
# Out:
#                                        missing_values  missing_values_per
# reanalysis_precip_amt_kg_per_m2                    12                0.64
# reanalysis_tdtr_k                                  12                0.64
# reanalysis_specific_humidity_g_per_kg              12                0.64
# reanalysis_relative_humidity_percent               12                0.64
# reanalysis_max_air_temp_k                          12                0.64
# reanalysis_dew_point_temp_k                        12                0.64
# reanalysis_min_air_temp_k                          12                0.64
# reanalysis_air_temp_k                              12                0.64
# reanalysis_avg_temp_k                              12                0.64
# precipitation_amt_mm                               15                0.80
# reanalysis_sat_precip_amt_mm                       15                0.80
# station_max_temp_c                                 23                1.23
# ndvi_sw                                            23                1.23
# ndvi_se                                            23                1.23
# station_min_temp_c                                 23                1.23
# station_precip_mm                                  27                1.44
# station_avg_temp_c                                 55                2.94
# station_diur_temp_rng_c                            55                2.94
# ndvi_nw                                            63                3.37
# ndvi_ne                                           237               12.66
# total_cases                                       416               22.22

# %% [markdown]
# - Here, we see that there are some missing values.
# - *ndvi_ne* is the feature with the higher number of missing values.

# %% [markdown]
# ### Line plot of total_cases for both cities

# %%
dengue_dataset_labeled['week_start_date'] = pd.to_datetime(dengue_dataset_labeled['week_start_date'])

du.show_lineplot(dengue_dataset_labeled, xvalue='week_start_date', yvalue='total_cases', hue='city')

# %% [markdown]
# The evolution of the number of total cases in both cities is quite diferent. For this reason, each city should be explored separately.

# %% [markdown]
# ### Boxplots

# %%
du.show_boxplot(dengue_dataset_labeled[dengue_dataset_labeled['city']=='sj'], exclude=['year'])
# Out:
# 20190618 - 17:M:12: show_bloxplot: omiting city
# 20190618 - 17:M:12: show_bloxplot: omiting year
# 20190618 - 17:M:12: show_bloxplot: omiting week_start_date

# %%
du.show_boxplot(dengue_dataset_labeled[dengue_dataset_labeled['city']=='iq'], exclude=['year'])
# Out:
# 20190618 - 17:M:14: show_bloxplot: omiting city
# 20190618 - 17:M:14: show_bloxplot: omiting year
# 20190618 - 17:M:14: show_bloxplot: omiting week_start_date

# %% [markdown]
# ### Temperature conversion
# In respect to temeperature features, it seems that some of them are expressed different units.

# %%
import pytemperature

features = ['reanalysis_air_temp_k', 'reanalysis_dew_point_temp_k', 
            'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
            'reanalysis_avg_temp_k']

# Conversion kelvin to celsius
dengue_dataset_labeled[features] = dengue_dataset_labeled[features].apply(pytemperature.k2c, axis=1)
du.show_boxplot(dengue_dataset_labeled, exclude=['year'])
# Out:
# 20191016 - 20:M:02: show_bloxplot: omiting city
# 20191016 - 20:M:02: show_bloxplot: omiting year
# 20191016 - 20:M:02: show_bloxplot: omiting week_start_date

# %% [markdown]
# **NOTE:** reanalysis_tdtr_c takes extreme temperature values, I wil remove that feature at the moment.

# %% [markdown]
# ### Correlation matrix for each city
#
# ####  San Juan

# %%
du.show_heatmap(dengue_dataset_labeled[dengue_dataset_labeled['city']=='sj'], exclude = ['city'])

# %% [markdown]
# #### Iquitos

# %%
du.show_heatmap(dengue_dataset_labeled[dengue_dataset_labeled['city']=='iq'], exclude = ['city'])

# %% [markdown]
# - For both cities, the label (total_cases) doesn't show correlation with other features
# - There is colineality among features, for example temeperature features. It will be necesary some feature selection to avoid this colineality.
# - In the next plot we can see the relationship betwen the features and the label:

# %%
du.show_feature_correlation(dengue_dataset_labeled[dengue_dataset_labeled['city']=='sj'], 
                            label = 'total_cases', 
                            title= 'Feature vs Label correlation (San Juan)', 
                            exclude = ['city'])

# %%
du.show_feature_correlation(dengue_dataset_labeled[dengue_dataset_labeled['city']=='iq'], 
                            label = 'total_cases', 
                            title= 'Feature vs Label correlation (Iquitos)', 
                            exclude = ['city'])

# %% [markdown]
# ### Feature analysis
#
# - Missing values
# - Variability
# - Correlation with label

# %%
import seaborn as sns

def get_feature_analysis(df):
    
    features_analysis = pd.DataFrame()

    for city in df.loc[:,'city'].unique():

        temp = pd.DataFrame()
        df_city = df.loc[df.loc[:,'city']==city,:]

        # number of missing values
        describe_df = pd.DataFrame(df_city.describe().T)
        describe_df.loc[:,'count'].max()

        max_number_of_rows = describe_df.loc[:,'count'].max()
        number_of_values   = describe_df.loc[:,'count']

        temp.loc[:,'missing_values'] = max_number_of_rows - number_of_values

        # feature variability

        temp['variance'] = df_city.var(axis=0)
        temp['cv'] =  df_city.std(axis=0) / df_city.mean(axis=0)

        # correlation with label
        if 'total_cases' in df_city.columns:
            temp['label_corr'] = np.abs(df_city.corr()['total_cases'])

        temp['city'] = city

        features_analysis = pd.concat([features_analysis, temp], axis=0)
        
    return features_analysis
    

def get_last_weeks_data(df):
    
    train_dataset_lastweeks = pd.DataFrame()

    for city in df.loc[:,'city'].unique():

        temp = df.loc[df.loc[:,'city']==city,:]

        climate_variables = temp.columns.copy()
        
        if 'total_cases' in climate_variables:
            climate_variables = climate_variables.drop('total_cases')   
        
        
        climate_variables = climate_variables.drop(['weekofyear', 'city', 'week_start_date', 'year'])

        for j, climate_variable in enumerate(climate_variables):
            temp.loc[:,climate_variable] = (temp.sort_values(['city', 'year', 'weekofyear'], 
                                                       ascending=True).loc[:,climate_variable]
                                           .rolling(window=12).median())


        train_dataset_lastweeks = pd.concat([train_dataset_lastweeks, temp], axis=0)    
    
    return train_dataset_lastweeks


    
features_analysis = get_feature_analysis(dengue_dataset_labeled)

features_analysis.sort_values('label_corr', ascending=False)

features_analysis.loc[features_analysis['city'] == 'sj',:].sort_values('label_corr', ascending=False)
# Out:
#                                        missing_values     variance        cv  \
# total_cases                                     260.0  2640.045440  1.503234
# weekofyear                                        0.0   225.612541  0.566736
# year                                              0.0    44.257049  0.003324
# reanalysis_specific_humidity_g_per_kg             8.0     2.525042  0.095748
# reanalysis_dew_point_temp_c                       8.0     2.536002  0.072367
# station_avg_temp_c                                8.0     2.016629  0.052471
# reanalysis_max_air_temp_c                         8.0     1.620665  0.044997
# station_max_temp_c                                8.0     2.940070  0.054222
# reanalysis_min_air_temp_c                         8.0     1.725269  0.054253
# reanalysis_air_temp_c                             8.0     1.567205  0.048006
# station_min_temp_c                                8.0     2.304949  0.066850
# reanalysis_avg_temp_c                             8.0     1.522995  0.047130
# reanalysis_relative_humidity_percent              8.0    11.522242  0.043247
# reanalysis_precip_amt_kg_per_m2                   8.0  1259.503525  1.223330
# ndvi_nw                                          60.0     0.008493  1.517477
# reanalysis_tdtr_k                                 8.0     0.245961  0.195899
# reanalysis_sat_precip_amt_mm                     11.0  1787.097606  1.261074
# precipitation_amt_mm                             11.0  1787.097606  1.261074
# station_precip_mm                                 8.0   966.704496  1.094843
# ndvi_ne                                         234.0     0.013103  2.268783
# station_diur_temp_rng_c                           8.0     0.711913  0.127339
# ndvi_se                                          20.0     0.003530  0.334665
# ndvi_sw                                          20.0     0.003146  0.343800
#
#                                        label_corr city
# total_cases                              1.000000   sj
# weekofyear                               0.287134   sj
# year                                     0.212690   sj
# reanalysis_specific_humidity_g_per_kg    0.207947   sj
# reanalysis_dew_point_temp_c              0.203774   sj
# station_avg_temp_c                       0.196617   sj
# reanalysis_max_air_temp_c                0.194532   sj
# station_max_temp_c                       0.189901   sj
# reanalysis_min_air_temp_c                0.187943   sj
# reanalysis_air_temp_c                    0.181917   sj
# station_min_temp_c                       0.177012   sj
# reanalysis_avg_temp_c                    0.175267   sj
# reanalysis_relative_humidity_percent     0.144045   sj
# reanalysis_precip_amt_kg_per_m2          0.107457   sj
# ndvi_nw                                  0.075307   sj
# reanalysis_tdtr_k                        0.067600   sj
# reanalysis_sat_precip_amt_mm             0.060211   sj
# precipitation_amt_mm                     0.060211   sj
# station_precip_mm                        0.051759   sj
# ndvi_ne                                  0.037639   sj
# station_diur_temp_rng_c                  0.034630   sj
# ndvi_se                                  0.001113   sj
# ndvi_sw                                  0.000333   sj

# %%
features_analysis.loc[features_analysis['city'] == 'iq',:].sort_values('label_corr', ascending=False)
# Out:
#                                        missing_values     variance        cv  \
# total_cases                                     156.0   115.895524  1.422992
# reanalysis_specific_humidity_g_per_kg             4.0     1.988448  0.082350
# reanalysis_dew_point_temp_c                       4.0     1.900951  0.061653
# reanalysis_min_air_temp_c                         4.0     2.695061  0.083409
# station_min_temp_c                               15.0     1.619907  0.060114
# year                                              0.0    14.271111  0.001883
# reanalysis_tdtr_k                                 4.0     5.670046  0.257890
# reanalysis_relative_humidity_percent              4.0    54.541683  0.083108
# station_avg_temp_c                               47.0     0.791359  0.032309
# reanalysis_precip_amt_kg_per_m2                   4.0  2650.583315  0.842726
# reanalysis_air_temp_c                             4.0     1.336325  0.046812
# reanalysis_sat_precip_amt_mm                      4.0  1194.191597  0.550462
# precipitation_amt_mm                              4.0  1194.191597  0.550462
# reanalysis_avg_temp_c                             4.0     1.760075  0.051102
# station_max_temp_c                               15.0     1.745425  0.038863
# station_diur_temp_rng_c                          47.0     2.344954  0.144370
# reanalysis_max_air_temp_c                         4.0     5.429178  0.068717
# station_precip_mm                                19.0  3444.486863  1.049369
# ndvi_se                                           3.0     0.005782  0.301647
# ndvi_sw                                           3.0     0.007407  0.318327
# ndvi_ne                                           3.0     0.006372  0.301723
# weekofyear                                        0.0   224.773552  0.566512
# ndvi_nw                                           3.0     0.006127  0.317989
#
#                                        label_corr city
# total_cases                              1.000000   iq
# reanalysis_specific_humidity_g_per_kg    0.236476   iq
# reanalysis_dew_point_temp_c              0.230401   iq
# reanalysis_min_air_temp_c                0.214514   iq
# station_min_temp_c                       0.211702   iq
# year                                     0.179451   iq
# reanalysis_tdtr_k                        0.134425   iq
# reanalysis_relative_humidity_percent     0.130083   iq
# station_avg_temp_c                       0.113070   iq
# reanalysis_precip_amt_kg_per_m2          0.101171   iq
# reanalysis_air_temp_c                    0.097098   iq
# reanalysis_sat_precip_amt_mm             0.090171   iq
# precipitation_amt_mm                     0.090171   iq
# reanalysis_avg_temp_c                    0.079872   iq
# station_max_temp_c                       0.075279   iq
# station_diur_temp_rng_c                  0.058230   iq
# reanalysis_max_air_temp_c                0.056474   iq
# station_precip_mm                        0.042976   iq
# ndvi_se                                  0.041067   iq
# ndvi_sw                                  0.032999   iq
# ndvi_ne                                  0.020215   iq
# weekofyear                               0.011850   iq
# ndvi_nw                                  0.009586   iq

# %% [markdown]
# Correlation among features and the label is quite low for both cities and for all features. For San Juan, variables more interesting could be:
#
# - reanalysis_specific_humidity_g_per_kg,
# - reanalysis_dew_point_temp_c
# - station_avg_temp_c
# - reanalysis_max_air_temp_c
#
# Iquitos:
#
# - reanalysis_specific_humidity_g_per_kg
# - reanalysis_dew_point_temp_c
# - reanalysis_min_air_temp_c
# - station_min_temp_c
#
# But not one of these variables reach a correlation higher than 0.3.
#
# Then, I notice that, the weather of the previous weeks could affect to the number of cases. So I performed the same feature analysis using weather data of the last weeks:

# %%
#dengue_dataset_labeled = dengue_dataset_labeled.fillna(method='ffill')
train_dataset_lastweeks = get_last_weeks_data(dengue_dataset_labeled)
    
#train_dataset_lastweeks = train_dataset_lastweeks.loc[train_dataset_lastweeks.loc[:,'week_start_date']  >= '2002-01-01',:]
train_dataset_lastweeks.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#   city  year  weekofyear week_start_date  ndvi_ne  ndvi_nw  ndvi_se  ndvi_sw  \
# 0   sj  1990          18      1990-04-30      NaN      NaN      NaN      NaN
# 1   sj  1990          19      1990-05-07      NaN      NaN      NaN      NaN
# 2   sj  1990          20      1990-05-14      NaN      NaN      NaN      NaN
# 3   sj  1990          21      1990-05-21      NaN      NaN      NaN      NaN
# 4   sj  1990          22      1990-05-28      NaN      NaN      NaN      NaN
#
#    precipitation_amt_mm  reanalysis_precip_amt_kg_per_m2  \
# 0                   NaN                              NaN
# 1                   NaN                              NaN
# 2                   NaN                              NaN
# 3                   NaN                              NaN
# 4                   NaN                              NaN
#
#            ...            station_diur_temp_rng_c  station_max_temp_c  \
# 0          ...                                NaN                 NaN
# 1          ...                                NaN                 NaN
# 2          ...                                NaN                 NaN
# 3          ...                                NaN                 NaN
# 4          ...                                NaN                 NaN
#
#    station_min_temp_c  station_precip_mm  total_cases  reanalysis_air_temp_c  \
# 0                 NaN                NaN          4.0                    NaN
# 1                 NaN                NaN          5.0                    NaN
# 2                 NaN                NaN          4.0                    NaN
# 3                 NaN                NaN          3.0                    NaN
# 4                 NaN                NaN          6.0                    NaN
#
#    reanalysis_dew_point_temp_c  reanalysis_max_air_temp_c  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
#    reanalysis_min_air_temp_c  reanalysis_avg_temp_c
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
# [5 rows x 25 columns]

# %%
features_analysis_lastweeks = get_feature_analysis(train_dataset_lastweeks)
features_analysis_lastweeks = features_analysis_lastweeks.sort_values('label_corr', ascending=False)
features_analysis_lastweeks = features_analysis_lastweeks.loc[features_analysis_lastweeks['label_corr'] > 0.2,:]
train_dataset_lastweeks.describe().T
# Out:
#                                         count         mean        std  \
# year                                   1872.0  2003.194979   6.292268
# weekofyear                             1872.0    26.489316  15.006319
# ndvi_ne                                 696.0     0.243930   0.071598
# ndvi_nw                                1358.0     0.143993   0.102906
# ndvi_se                                1728.0     0.202642   0.046027
# ndvi_sw                                1728.0     0.200172   0.060215
# precipitation_amt_mm                   1698.0    37.227014  25.022236
# reanalysis_precip_amt_kg_per_m2        1706.0    32.572767  22.465630
# reanalysis_relative_humidity_percent   1706.0    82.624843   6.480349
# reanalysis_sat_precip_amt_mm           1698.0    37.227014  25.022236
# reanalysis_specific_humidity_g_per_kg  1706.0    16.904740   1.295314
# reanalysis_tdtr_k                      1706.0     4.933763   3.413920
# station_avg_temp_c                     1464.0    27.289593   1.093266
# station_diur_temp_rng_c                1464.0     7.665731   1.872567
# station_max_temp_c                     1640.0    32.470610   1.567992
# station_min_temp_c                     1640.0    22.334024   1.307962
# station_precip_mm                      1540.0    29.473377  20.447387
# total_cases                            1456.0    24.675137  43.596000
# reanalysis_air_temp_c                  1706.0    25.637482   1.244528
# reanalysis_dew_point_temp_c            1706.0    22.272825   1.252996
# reanalysis_max_air_temp_c              1706.0    30.395985   2.995096
# reanalysis_min_air_temp_c              1706.0    22.682151   2.449532
# reanalysis_avg_temp_c                  1706.0    26.173620   1.046000
#
#                                                min          25%          50%  \
# year                                   1990.000000  1999.000000  2004.000000
# weekofyear                                1.000000    13.750000    26.000000
# ndvi_ne                                  -0.029525     0.227050     0.257936
# ndvi_nw                                  -0.092550     0.048319     0.150940
# ndvi_se                                   0.103286     0.168504     0.193857
# ndvi_sw                                   0.084177     0.155977     0.179529
# precipitation_amt_mm                      0.000000    16.945000    36.840000
# reanalysis_precip_amt_kg_per_m2           2.960000    15.550000    25.925000
# reanalysis_relative_humidity_percent     73.102857    77.919643    80.074643
# reanalysis_sat_precip_amt_mm              0.000000    16.945000    36.840000
# reanalysis_specific_humidity_g_per_kg    13.258571    15.820714    17.292500
# reanalysis_tdtr_k                         1.892857     2.392857     2.742857
# station_avg_temp_c                       24.571429    26.513839    27.577619
# station_diur_temp_rng_c                   5.342857     6.378571     6.871429
# station_max_temp_c                       27.800000    31.700000    32.800000
# station_min_temp_c                       19.650000    21.100000    22.200000
# station_precip_mm                         0.700000    15.250000    23.700000
# total_cases                               0.000000     5.000000    12.000000
# reanalysis_air_temp_c                    23.022143    24.639286    25.466071
# reanalysis_dew_point_temp_c              18.439286    21.251071    22.698571
# reanalysis_max_air_temp_c                25.900000    28.100000    29.400000
# reanalysis_min_air_temp_c                17.150000    20.450000    23.200000
# reanalysis_avg_temp_c                    23.642857    25.283036    26.183929
#
#                                                75%          max
# year                                   2008.000000  2013.000000
# weekofyear                               39.000000    53.000000
# ndvi_ne                                   0.292513     0.349493
# ndvi_nw                                   0.239214     0.346737
# ndvi_se                                   0.230286     0.361871
# ndvi_sw                                   0.245486     0.370658
# precipitation_amt_mm                     53.851250   112.610000
# reanalysis_precip_amt_kg_per_m2          44.551250   147.890000
# reanalysis_relative_humidity_percent     87.643036    96.066429
# reanalysis_sat_precip_amt_mm             53.851250   112.610000
# reanalysis_specific_humidity_g_per_kg    17.967857    19.408571
# reanalysis_tdtr_k                         7.935714    13.735714
# station_avg_temp_c                       28.121429    29.335714
# station_diur_temp_rng_c                   9.118750    13.137500
# station_max_temp_c                       33.450000    36.000000
# station_min_temp_c                       23.600000    25.300000
# station_precip_mm                        37.150000   109.850000
# total_cases                              28.000000   461.000000
# reanalysis_air_temp_c                    26.735714    28.136429
# reanalysis_dew_point_temp_c              23.302679    24.473571
# reanalysis_max_air_temp_c                32.550000    38.000000
# reanalysis_min_air_temp_c                24.900000    26.200000
# reanalysis_avg_temp_c                    27.021429    28.300000

# %% [markdown]
# ### Density plots
#
# These plots confirms the observed in previous analysis. Cities should be studied by saparate. Weather and total_cases are diferent in both cities.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#features = train_dataset.columns.drop(['week_start_date'])

fig = plt.figure(figsize=(20, 20))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i, column in enumerate(features):

    ax = fig.add_subplot(5, 5, i+1)

    data_sj = train_dataset[train_dataset['city']=='sj'][column]
    data_iq = train_dataset[train_dataset['city']=='iq'][column]
    
    sns.distplot(data_sj, hist=False, kde=True, bins=int(180/5), color = 'salmon', 
             hist_kws={'edgecolor':'black'}, kde_kws={'linewidth': 3})
    
    sns.distplot(data_iq, hist=False, kde=True, bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'}, kde_kws={'linewidth': 3})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8d1a30087435> in <module>
#       7 fig.subplots_adjust(hspace=0.4, wspace=0.4)
#       8
# ----> 9 for i, column in enumerate(features):
#      10
#      11     ax = fig.add_subplot(5, 5, i+1)
#
# NameError: name 'features' is not defined

# %% [markdown]
# ### Scatter plots
#
# Here, I plot the scatter plot of each feature vs total_cases for both cities. (Blue = san juan, Salmon = Iquitos)

# %%
features = train_dataset.columns.drop(['city', 'total_cases'])

fig = plt.figure(figsize=(30, 30))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i, column in enumerate(features):

    ax = fig.add_subplot(6, 4, i+1)
    
    sns.scatterplot(x=column, y="total_cases", 
                    hue='city', data=train_dataset, 
                    palette = dict(iq="salmon", 
                                   sj="c"))

# %% [markdown]
# ## Add new variables

# %%
## Add month of the year

train_dataset['week_start_date'] = pd.to_datetime(train_dataset['week_start_date'])
train_dataset['monthofyear'] = train_dataset['week_start_date'].apply(lambda x: x.month)


# High correlation between ndvi_nw-ndvi-ne and ndvi-sw-ndvi-se
# Add the mean of each pair that indicates the level of vegetation in the north and south of both cities.

# Features engineering

train_dataset['ndvi_north'] = train_dataset[['ndvi_nw', 'ndvi_ne']].mean(axis=1)
train_dataset['ndvi_south'] = train_dataset[['ndvi_sw', 'ndvi_se']].mean(axis=1)

#Remove feature

train_dataset = train_dataset.drop(['ndvi_sw', 'ndvi_nw', 'ndvi_ne', 'ndvi_se', 'week_start_date'], axis=1)

# %%
train_dataset.head()
# Out:
#   city  year  weekofyear  precipitation_amt_mm  \
# 0   sj  1990          18                 12.42
# 1   sj  1990          19                 22.82
# 2   sj  1990          20                 34.54
# 3   sj  1990          21                 15.36
# 4   sj  1990          22                  7.52
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# 1                            17.94                             77.368571
# 2                            26.10                             82.052857
# 3                            13.90                             80.337143
# 4                            12.20                             80.460000
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# 0                         12.42                              14.012857
# 1                         22.82                              15.372857
# 2                         34.54                              16.848571
# 3                         15.36                              16.672857
# 4                          7.52                              17.210000
#
#    reanalysis_tdtr_k  station_avg_temp_c     ...      station_precip_mm  \
# 0           2.628571           25.442857     ...                   16.0
# 1           2.371429           26.714286     ...                    8.6
# 2           2.300000           26.714286     ...                   41.4
# 3           2.428571           27.471429     ...                    4.0
# 4           3.014286           28.942857     ...                    5.8
#
#    total_cases  reanalysis_air_temp_c  reanalysis_dew_point_temp_c  \
# 0            4              24.422857                    19.264286
# 1            5              25.061429                    20.801429
# 2            4              25.631429                    22.284286
# 3            3              25.837143                    22.160000
# 4            6              26.368571                    22.671429
#
#    reanalysis_max_air_temp_c  reanalysis_min_air_temp_c  \
# 0                      26.65                      22.75
# 1                      27.75                      23.25
# 2                      27.35                      24.15
# 3                      28.25                      23.85
# 4                      28.75                      24.35
#
#    reanalysis_avg_temp_c  monthofyear  ndvi_north  ndvi_south
# 0              24.592857            4    0.113162    0.188050
# 1              25.292857            5    0.156037    0.158921
# 2              25.728571            5    0.102608    0.164021
# 3              26.078571            5    0.186850    0.231721
# 4              26.514286            5    0.229200    0.249270
#
# [5 rows x 23 columns]
